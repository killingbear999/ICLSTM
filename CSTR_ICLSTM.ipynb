# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, Conv1D, MaxPooling1D, Flatten
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations
import pickle

# %%
# specifying constant parameters

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
Q_s = 0.0
T_s = 401.8727
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314
C_A0s = 4
C_As = 1.9537
t_final = 0.005
t_step = 1e-4
P = np.array([[1060, 22], [22, 0.52]])

num_step = 10

# %%
# generating inputs and initial states for CSTR, all expressed in deviation form

u1_list = np.linspace(-3.5, 3.5, 4, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 4, endpoint=True)
T_initial = np.linspace(300, 600, 100, endpoint=True) - T_s
CA_initial = np.linspace(0, 6, 100, endpoint=True) - C_As

# %%
# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 372:
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
# Out:
# number of initial conditions: 772
# shape of x_deviation is (772, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """

    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time

    C_A = C_A_initial + C_As
    T = T_initial + T_s

    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)

        T += dTdt * t_step
        C_A += dCAdt * t_step

        if i % 5 == 0:
          C_A_list.append(C_A - C_As)  # in deviation form
          T_list.append(T - T_s)  # in deviation form

    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()
CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()

for u1 in u1_list:
    C_A0 = u1 + C_A0s

    for u2 in u2_list:
        Q = u2 + Q_s

        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)

            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
CA0_input = np.array(CA0_input)
print(CA0_input.shape)
CA_output = np.array(CA_output)
print(CA_output.shape)
# Out:
# (12352,)
# (12352, 10)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

CA0_input_neg = -np.array(CA0_input)
CA0_input_neg = CA0_input_neg.reshape(-1,1,1)

Q_input_neg = -np.array(Q_input)
Q_input_neg = Q_input_neg.reshape(-1,1,1)

CA_input_neg = -np.array(CA_input)
CA_input_neg = CA_input_neg.reshape(-1,1,1)

T_input_neg = -np.array(T_input)
T_input_neg = T_input_neg.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input, T_input_neg, CA_input_neg, Q_input_neg, CA0_input_neg), axis=2)

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""

RNN_input = RNN_input.repeat(num_step, axis=1)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (12352, 10, 8)

# %%
# checking the input is duplicated 100 times for each time step
print(RNN_input[0, 0])
print(RNN_input[0, 1])
# Out:
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, num_step, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, num_step, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (12352, 10, 2)

# %%
# checking output
print(RNN_output[0, :5])
# Out:
# [[-74.82498608   1.43869052]
#  [-75.94937347   1.43097798]
#  [-77.07255531   1.4233169 ]
#  [-78.19443649   1.41570516]
#  [-79.31492759   1.4081408 ]]

# %%
num_dims = 8

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.StandardScaler().fit(X_train.reshape(-1, num_dims))
scaler_y = preprocessing.StandardScaler().fit(y_train.reshape(-1, 2))


X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)

# %%
print("mean of input T, CA, Q, CA0 = ", scaler_X.mean_)
print("std of input T, CA, Q, CA0 = ", scaler_X.scale_)
print("mean of output T, CA = ", scaler_y.mean_)
print("std of output T, CA = ", scaler_y.scale_)
# Out:
# mean of input T, CA, Q, CA0 =  [-6.16908217e-01  1.67119614e-02  1.92767368e+02  1.16045956e-02
#   6.16908217e-01 -1.67119614e-02 -1.92767368e+02 -1.16045956e-02]
# std of input T, CA, Q, CA0 =  [3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00
#  3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00]
# mean of output T, CA =  [-0.75373917  0.01958435]
# std of output T, CA =  [38.78474393  0.84533936]

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

# input convex LSTM
input = Input(shape=(X_train.shape[1],X_train.shape[2]))
x_skip = input
x = LSTM(64, activation='relu', return_sequences=True, kernel_constraint=tf.keras.constraints.NonNeg())(input)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Add()([x, x_skip])
x = LSTM(64, activation='relu', return_sequences=True, kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Dense(2, activation='linear', kernel_constraint=tf.keras.constraints.NonNeg())(x)
model = Model(input, x)

model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
history = model.fit(X_train, y_train, epochs=500, batch_size=256, validation_split=0.25, verbose=2)
model.summary()
# Out:
# Epoch 1/500
# 26/26 - 5s - loss: 1.0499 - mean_squared_error: 1.0499 - val_loss: 0.9078 - val_mean_squared_error: 0.9078 - 5s/epoch - 195ms/step
# Epoch 2/500
# 26/26 - 2s - loss: 0.8604 - mean_squared_error: 0.8604 - val_loss: 0.8196 - val_mean_squared_error: 0.8196 - 2s/epoch - 84ms/step
# Epoch 3/500
# 26/26 - 1s - loss: 0.7776 - mean_squared_error: 0.7776 - val_loss: 0.7295 - val_mean_squared_error: 0.7295 - 1s/epoch - 56ms/step
# Epoch 4/500
# 26/26 - 1s - loss: 0.6659 - mean_squared_error: 0.6659 - val_loss: 0.5989 - val_mean_squared_error: 0.5989 - 1s/epoch - 50ms/step
# Epoch 5/500
# 26/26 - 1s - loss: 0.5548 - mean_squared_error: 0.5548 - val_loss: 0.5106 - val_mean_squared_error: 0.5106 - 1s/epoch - 45ms/step
# Epoch 6/500
# 26/26 - 1s - loss: 0.4827 - mean_squared_error: 0.4827 - val_loss: 0.4515 - val_mean_squared_error: 0.4515 - 1s/epoch - 44ms/step
# Epoch 7/500
# 26/26 - 1s - loss: 0.4329 - mean_squared_error: 0.4329 - val_loss: 0.4098 - val_mean_squared_error: 0.4098 - 1s/epoch - 43ms/step
# Epoch 8/500
# 26/26 - 1s - loss: 0.3961 - mean_squared_error: 0.3961 - val_loss: 0.3776 - val_mean_squared_error: 0.3776 - 1s/epoch - 43ms/step
# Epoch 9/500
# 26/26 - 2s - loss: 0.3666 - mean_squared_error: 0.3666 - val_loss: 0.3510 - val_mean_squared_error: 0.3510 - 2s/epoch - 83ms/step
# Epoch 10/500
# 26/26 - 3s - loss: 0.3416 - mean_squared_error: 0.3416 - val_loss: 0.3278 - val_mean_squared_error: 0.3278 - 3s/epoch - 108ms/step
# Epoch 11/500
# 26/26 - 3s - loss: 0.3196 - mean_squared_error: 0.3196 - val_loss: 0.3074 - val_mean_squared_error: 0.3074 - 3s/epoch - 109ms/step
# Epoch 12/500
# 26/26 - 3s - loss: 0.2999 - mean_squared_error: 0.2999 - val_loss: 0.2887 - val_mean_squared_error: 0.2887 - 3s/epoch - 104ms/step
# Epoch 13/500
# 26/26 - 3s - loss: 0.2821 - mean_squared_error: 0.2821 - val_loss: 0.2720 - val_mean_squared_error: 0.2720 - 3s/epoch - 115ms/step
# Epoch 14/500
# 26/26 - 2s - loss: 0.2660 - mean_squared_error: 0.2660 - val_loss: 0.2569 - val_mean_squared_error: 0.2569 - 2s/epoch - 84ms/step
# Epoch 15/500
# 26/26 - 3s - loss: 0.2515 - mean_squared_error: 0.2515 - val_loss: 0.2431 - val_mean_squared_error: 0.2431 - 3s/epoch - 115ms/step
# Epoch 16/500
# 26/26 - 2s - loss: 0.2381 - mean_squared_error: 0.2381 - val_loss: 0.2305 - val_mean_squared_error: 0.2305 - 2s/epoch - 94ms/step
# Epoch 17/500
# 26/26 - 1s - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2187 - val_mean_squared_error: 0.2187 - 1s/epoch - 45ms/step
# Epoch 18/500
# 26/26 - 1s - loss: 0.2143 - mean_squared_error: 0.2143 - val_loss: 0.2077 - val_mean_squared_error: 0.2077 - 1s/epoch - 45ms/step
# Epoch 19/500
# 26/26 - 1s - loss: 0.2036 - mean_squared_error: 0.2036 - val_loss: 0.1976 - val_mean_squared_error: 0.1976 - 1s/epoch - 44ms/step
# Epoch 20/500
# 26/26 - 1s - loss: 0.1937 - mean_squared_error: 0.1937 - val_loss: 0.1879 - val_mean_squared_error: 0.1879 - 1s/epoch - 44ms/step
# Epoch 21/500
# 26/26 - 1s - loss: 0.1842 - mean_squared_error: 0.1842 - val_loss: 0.1789 - val_mean_squared_error: 0.1789 - 1s/epoch - 45ms/step
# Epoch 22/500
# 26/26 - 1s - loss: 0.1753 - mean_squared_error: 0.1753 - val_loss: 0.1703 - val_mean_squared_error: 0.1703 - 1s/epoch - 45ms/step
# Epoch 23/500
# 26/26 - 1s - loss: 0.1670 - mean_squared_error: 0.1670 - val_loss: 0.1622 - val_mean_squared_error: 0.1622 - 1s/epoch - 45ms/step
# Epoch 24/500
# 26/26 - 1s - loss: 0.1591 - mean_squared_error: 0.1591 - val_loss: 0.1546 - val_mean_squared_error: 0.1546 - 1s/epoch - 45ms/step
# Epoch 25/500
# 26/26 - 2s - loss: 0.1516 - mean_squared_error: 0.1516 - val_loss: 0.1474 - val_mean_squared_error: 0.1474 - 2s/epoch - 62ms/step
# Epoch 26/500
# 26/26 - 2s - loss: 0.1445 - mean_squared_error: 0.1445 - val_loss: 0.1406 - val_mean_squared_error: 0.1406 - 2s/epoch - 82ms/step
# Epoch 27/500
# 26/26 - 1s - loss: 0.1378 - mean_squared_error: 0.1378 - val_loss: 0.1341 - val_mean_squared_error: 0.1341 - 1s/epoch - 56ms/step
# Epoch 28/500
# 26/26 - 1s - loss: 0.1315 - mean_squared_error: 0.1315 - val_loss: 0.1280 - val_mean_squared_error: 0.1280 - 1s/epoch - 45ms/step
# Epoch 29/500
# 26/26 - 1s - loss: 0.1255 - mean_squared_error: 0.1255 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - 1s/epoch - 45ms/step
# Epoch 30/500
# 26/26 - 1s - loss: 0.1197 - mean_squared_error: 0.1197 - val_loss: 0.1167 - val_mean_squared_error: 0.1167 - 1s/epoch - 44ms/step
# Epoch 31/500
# 26/26 - 1s - loss: 0.1143 - mean_squared_error: 0.1143 - val_loss: 0.1114 - val_mean_squared_error: 0.1114 - 1s/epoch - 46ms/step
# Epoch 32/500
# 26/26 - 1s - loss: 0.1091 - mean_squared_error: 0.1091 - val_loss: 0.1064 - val_mean_squared_error: 0.1064 - 1s/epoch - 44ms/step
# Epoch 33/500
# 26/26 - 1s - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.1017 - val_mean_squared_error: 0.1017 - 1s/epoch - 45ms/step
# Epoch 34/500
# 26/26 - 1s - loss: 0.0996 - mean_squared_error: 0.0996 - val_loss: 0.0971 - val_mean_squared_error: 0.0971 - 1s/epoch - 50ms/step
# Epoch 35/500
# 26/26 - 1s - loss: 0.0951 - mean_squared_error: 0.0951 - val_loss: 0.0929 - val_mean_squared_error: 0.0929 - 1s/epoch - 55ms/step
# Epoch 36/500
# 26/26 - 2s - loss: 0.0909 - mean_squared_error: 0.0909 - val_loss: 0.0888 - val_mean_squared_error: 0.0888 - 2s/epoch - 87ms/step
# Epoch 37/500
# 26/26 - 2s - loss: 0.0869 - mean_squared_error: 0.0869 - val_loss: 0.0849 - val_mean_squared_error: 0.0849 - 2s/epoch - 58ms/step
# Epoch 38/500
# 26/26 - 1s - loss: 0.0831 - mean_squared_error: 0.0831 - val_loss: 0.0812 - val_mean_squared_error: 0.0812 - 1s/epoch - 44ms/step
# Epoch 39/500
# 26/26 - 1s - loss: 0.0795 - mean_squared_error: 0.0795 - val_loss: 0.0777 - val_mean_squared_error: 0.0777 - 1s/epoch - 45ms/step
# Epoch 40/500
# 26/26 - 1s - loss: 0.0760 - mean_squared_error: 0.0760 - val_loss: 0.0744 - val_mean_squared_error: 0.0744 - 1s/epoch - 50ms/step
# Epoch 41/500
# 26/26 - 1s - loss: 0.0728 - mean_squared_error: 0.0728 - val_loss: 0.0712 - val_mean_squared_error: 0.0712 - 1s/epoch - 50ms/step
# Epoch 42/500
# 26/26 - 1s - loss: 0.0696 - mean_squared_error: 0.0696 - val_loss: 0.0682 - val_mean_squared_error: 0.0682 - 1s/epoch - 45ms/step
# Epoch 43/500
# 26/26 - 1s - loss: 0.0667 - mean_squared_error: 0.0667 - val_loss: 0.0653 - val_mean_squared_error: 0.0653 - 1s/epoch - 44ms/step
# Epoch 44/500
# 26/26 - 1s - loss: 0.0638 - mean_squared_error: 0.0638 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - 1s/epoch - 50ms/step
# Epoch 45/500
# 26/26 - 1s - loss: 0.0611 - mean_squared_error: 0.0611 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - 1s/epoch - 57ms/step
# Epoch 46/500
# 26/26 - 3s - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - 3s/epoch - 121ms/step
# Epoch 47/500
# 26/26 - 2s - loss: 0.0561 - mean_squared_error: 0.0561 - val_loss: 0.0550 - val_mean_squared_error: 0.0550 - 2s/epoch - 83ms/step
# Epoch 48/500
# 26/26 - 2s - loss: 0.0537 - mean_squared_error: 0.0537 - val_loss: 0.0527 - val_mean_squared_error: 0.0527 - 2s/epoch - 82ms/step
# Epoch 49/500
# 26/26 - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - val_loss: 0.0505 - val_mean_squared_error: 0.0505 - 2s/epoch - 84ms/step
# Epoch 50/500
# 26/26 - 1s - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0485 - val_mean_squared_error: 0.0485 - 1s/epoch - 45ms/step
# Epoch 51/500
# 26/26 - 1s - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0465 - val_mean_squared_error: 0.0465 - 1s/epoch - 50ms/step
# Epoch 52/500
# 26/26 - 3s - loss: 0.0453 - mean_squared_error: 0.0453 - val_loss: 0.0446 - val_mean_squared_error: 0.0446 - 3s/epoch - 100ms/step
# Epoch 53/500
# 26/26 - 2s - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0428 - val_mean_squared_error: 0.0428 - 2s/epoch - 81ms/step
# Epoch 54/500
# 26/26 - 1s - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.0410 - val_mean_squared_error: 0.0410 - 1s/epoch - 45ms/step
# Epoch 55/500
# 26/26 - 1s - loss: 0.0400 - mean_squared_error: 0.0400 - val_loss: 0.0393 - val_mean_squared_error: 0.0393 - 1s/epoch - 44ms/step
# Epoch 56/500
# 26/26 - 1s - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0378 - val_mean_squared_error: 0.0378 - 1s/epoch - 50ms/step
# Epoch 57/500
# 26/26 - 1s - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0362 - val_mean_squared_error: 0.0362 - 1s/epoch - 45ms/step
# Epoch 58/500
# 26/26 - 1s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 1s/epoch - 44ms/step
# Epoch 59/500
# 26/26 - 1s - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0334 - val_mean_squared_error: 0.0334 - 1s/epoch - 44ms/step
# Epoch 60/500
# 26/26 - 1s - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0321 - val_mean_squared_error: 0.0321 - 1s/epoch - 44ms/step
# Epoch 61/500
# 26/26 - 1s - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0308 - val_mean_squared_error: 0.0308 - 1s/epoch - 45ms/step
# Epoch 62/500
# 26/26 - 2s - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 2s/epoch - 61ms/step
# Epoch 63/500
# 26/26 - 2s - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - 2s/epoch - 83ms/step
# Epoch 64/500
# 26/26 - 1s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - 1s/epoch - 54ms/step
# Epoch 65/500
# 26/26 - 1s - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - 1s/epoch - 45ms/step
# Epoch 66/500
# 26/26 - 1s - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - 1s/epoch - 45ms/step
# Epoch 67/500
# 26/26 - 1s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - 1s/epoch - 45ms/step
# Epoch 68/500
# 26/26 - 1s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - 1s/epoch - 44ms/step
# Epoch 69/500
# 26/26 - 1s - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - 1s/epoch - 44ms/step
# Epoch 70/500
# 26/26 - 1s - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - 1s/epoch - 44ms/step
# Epoch 71/500
# 26/26 - 1s - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - 1s/epoch - 44ms/step
# Epoch 72/500
# 26/26 - 1s - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - 1s/epoch - 47ms/step
# Epoch 73/500
# 26/26 - 2s - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - 2s/epoch - 86ms/step
# Epoch 74/500
# 26/26 - 2s - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0185 - val_mean_squared_error: 0.0185 - 2s/epoch - 65ms/step
# Epoch 75/500
# 26/26 - 1s - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 1s/epoch - 44ms/step
# Epoch 76/500
# 26/26 - 1s - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0171 - val_mean_squared_error: 0.0171 - 1s/epoch - 44ms/step
# Epoch 77/500
# 26/26 - 1s - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - 1s/epoch - 45ms/step
# Epoch 78/500
# 26/26 - 1s - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - 1s/epoch - 44ms/step
# Epoch 79/500
# 26/26 - 1s - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - 1s/epoch - 45ms/step
# Epoch 80/500
# 26/26 - 1s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 1s/epoch - 44ms/step
# Epoch 81/500
# 26/26 - 1s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 1s/epoch - 44ms/step
# Epoch 82/500
# 26/26 - 1s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 1s/epoch - 44ms/step
# Epoch 83/500
# 26/26 - 2s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 2s/epoch - 79ms/step
# Epoch 84/500
# 26/26 - 2s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 2s/epoch - 76ms/step
# Epoch 85/500
# 26/26 - 1s - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - 1s/epoch - 44ms/step
# Epoch 86/500
# 26/26 - 1s - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 1s/epoch - 44ms/step
# Epoch 87/500
# 26/26 - 1s - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 1s/epoch - 44ms/step
# Epoch 88/500
# 26/26 - 1s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 1s/epoch - 44ms/step
# Epoch 89/500
# 26/26 - 1s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 1s/epoch - 44ms/step
# Epoch 90/500
# 26/26 - 1s - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 1s/epoch - 44ms/step
# Epoch 91/500
# 26/26 - 1s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 1s/epoch - 50ms/step
# Epoch 92/500
# 26/26 - 1s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 1s/epoch - 45ms/step
# Epoch 93/500
# 26/26 - 2s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 2s/epoch - 69ms/step
# Epoch 94/500
# 26/26 - 2s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 2s/epoch - 84ms/step
# Epoch 95/500
# 26/26 - 1s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 1s/epoch - 52ms/step
# Epoch 96/500
# 26/26 - 1s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 1s/epoch - 44ms/step
# Epoch 97/500
# 26/26 - 1s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 1s/epoch - 44ms/step
# Epoch 98/500
# 26/26 - 1s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 1s/epoch - 44ms/step
# Epoch 99/500
# 26/26 - 1s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 1s/epoch - 44ms/step
# Epoch 100/500
# 26/26 - 1s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 1s/epoch - 45ms/step
# Epoch 101/500
# 26/26 - 1s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 1s/epoch - 44ms/step
# Epoch 102/500
# 26/26 - 1s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 1s/epoch - 44ms/step
# Epoch 103/500
# 26/26 - 2s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 2s/epoch - 60ms/step
# Epoch 104/500
# 26/26 - 2s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 2s/epoch - 85ms/step
# Epoch 105/500
# 26/26 - 1s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 1s/epoch - 53ms/step
# Epoch 106/500
# 26/26 - 1s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 1s/epoch - 44ms/step
# Epoch 107/500
# 26/26 - 1s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 1s/epoch - 45ms/step
# Epoch 108/500
# 26/26 - 1s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 1s/epoch - 44ms/step
# Epoch 109/500
# 26/26 - 1s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 1s/epoch - 44ms/step
# Epoch 110/500
# 26/26 - 1s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 1s/epoch - 44ms/step
# Epoch 111/500
# 26/26 - 1s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - 1s/epoch - 45ms/step
# Epoch 112/500
# 26/26 - 1s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - 1s/epoch - 45ms/step
# Epoch 113/500
# 26/26 - 1s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - 1s/epoch - 49ms/step
# Epoch 114/500
# 26/26 - 2s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - 2s/epoch - 86ms/step
# Epoch 115/500
# 26/26 - 2s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - 2s/epoch - 70ms/step
# Epoch 116/500
# 26/26 - 1s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - 1s/epoch - 44ms/step
# Epoch 117/500
# 26/26 - 1s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - 1s/epoch - 45ms/step
# Epoch 118/500
# 26/26 - 1s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - 1s/epoch - 45ms/step
# Epoch 119/500
# 26/26 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - 1s/epoch - 50ms/step
# Epoch 120/500
# 26/26 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - 1s/epoch - 45ms/step
# Epoch 121/500
# 26/26 - 1s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - 1s/epoch - 44ms/step
# Epoch 122/500
# 26/26 - 1s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - 1s/epoch - 46ms/step
# Epoch 123/500
# 26/26 - 1s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - 1s/epoch - 51ms/step
# Epoch 124/500
# 26/26 - 2s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - 2s/epoch - 84ms/step
# Epoch 125/500
# 26/26 - 2s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - 2s/epoch - 65ms/step
# Epoch 126/500
# 26/26 - 2s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - 2s/epoch - 85ms/step
# Epoch 127/500
# 26/26 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - 1s/epoch - 44ms/step
# Epoch 128/500
# 26/26 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - 1s/epoch - 44ms/step
# Epoch 129/500
# 26/26 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 1s/epoch - 45ms/step
# Epoch 130/500
# 26/26 - 2s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 2s/epoch - 66ms/step
# Epoch 131/500
# 26/26 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 1s/epoch - 48ms/step
# Epoch 132/500
# 26/26 - 2s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 2s/epoch - 59ms/step
# Epoch 133/500
# 26/26 - 2s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 2s/epoch - 86ms/step
# Epoch 134/500
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 54ms/step
# Epoch 135/500
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 44ms/step
# Epoch 136/500
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 44ms/step
# Epoch 137/500
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 44ms/step
# Epoch 138/500
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 46ms/step
# Epoch 139/500
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 45ms/step
# Epoch 140/500
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 45ms/step
# Epoch 141/500
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 44ms/step
# Epoch 142/500
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 51ms/step
# Epoch 143/500
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 86ms/step
# Epoch 144/500
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 69ms/step
# Epoch 145/500
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 1s/epoch - 45ms/step
# Epoch 146/500
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 147/500
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 1s/epoch - 46ms/step
# Epoch 148/500
# 26/26 - 1s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 1s/epoch - 50ms/step
# Epoch 149/500
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 1s/epoch - 45ms/step
# Epoch 150/500
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 1s/epoch - 44ms/step
# Epoch 151/500
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 1s/epoch - 44ms/step
# Epoch 152/500
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 1s/epoch - 53ms/step
# Epoch 153/500
# 26/26 - 2s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 2s/epoch - 85ms/step
# Epoch 154/500
# 26/26 - 2s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 2s/epoch - 62ms/step
# Epoch 155/500
# 26/26 - 1s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 1s/epoch - 44ms/step
# Epoch 156/500
# 26/26 - 2s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 2s/epoch - 84ms/step
# Epoch 157/500
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 1s/epoch - 51ms/step
# Epoch 158/500
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 1s/epoch - 44ms/step
# Epoch 159/500
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 1s/epoch - 45ms/step
# Epoch 160/500
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - 1s/epoch - 44ms/step
# Epoch 161/500
# 26/26 - 1s - loss: 9.8477e-04 - mean_squared_error: 9.8477e-04 - val_loss: 9.8217e-04 - val_mean_squared_error: 9.8217e-04 - 1s/epoch - 45ms/step
# Epoch 162/500
# 26/26 - 2s - loss: 9.4948e-04 - mean_squared_error: 9.4948e-04 - val_loss: 9.4946e-04 - val_mean_squared_error: 9.4946e-04 - 2s/epoch - 84ms/step
# Epoch 163/500
# 26/26 - 2s - loss: 9.2029e-04 - mean_squared_error: 9.2029e-04 - val_loss: 9.2116e-04 - val_mean_squared_error: 9.2116e-04 - 2s/epoch - 72ms/step
# Epoch 164/500
# 26/26 - 1s - loss: 8.9454e-04 - mean_squared_error: 8.9454e-04 - val_loss: 9.0064e-04 - val_mean_squared_error: 9.0064e-04 - 1s/epoch - 45ms/step
# Epoch 165/500
# 26/26 - 1s - loss: 8.7030e-04 - mean_squared_error: 8.7030e-04 - val_loss: 8.6792e-04 - val_mean_squared_error: 8.6792e-04 - 1s/epoch - 44ms/step
# Epoch 166/500
# 26/26 - 1s - loss: 8.4232e-04 - mean_squared_error: 8.4232e-04 - val_loss: 8.4384e-04 - val_mean_squared_error: 8.4384e-04 - 1s/epoch - 44ms/step
# Epoch 167/500
# 26/26 - 1s - loss: 8.1845e-04 - mean_squared_error: 8.1845e-04 - val_loss: 8.2243e-04 - val_mean_squared_error: 8.2243e-04 - 1s/epoch - 51ms/step
# Epoch 168/500
# 26/26 - 1s - loss: 7.9580e-04 - mean_squared_error: 7.9580e-04 - val_loss: 7.9711e-04 - val_mean_squared_error: 7.9711e-04 - 1s/epoch - 44ms/step
# Epoch 169/500
# 26/26 - 1s - loss: 7.8324e-04 - mean_squared_error: 7.8324e-04 - val_loss: 8.3889e-04 - val_mean_squared_error: 8.3889e-04 - 1s/epoch - 44ms/step
# Epoch 170/500
# 26/26 - 1s - loss: 7.8196e-04 - mean_squared_error: 7.8196e-04 - val_loss: 8.1215e-04 - val_mean_squared_error: 8.1215e-04 - 1s/epoch - 44ms/step
# Epoch 171/500
# 26/26 - 1s - loss: 7.6037e-04 - mean_squared_error: 7.6037e-04 - val_loss: 7.4736e-04 - val_mean_squared_error: 7.4736e-04 - 1s/epoch - 56ms/step
# Epoch 172/500
# 26/26 - 2s - loss: 7.5990e-04 - mean_squared_error: 7.5990e-04 - val_loss: 7.2363e-04 - val_mean_squared_error: 7.2363e-04 - 2s/epoch - 94ms/step
# Epoch 173/500
# 26/26 - 2s - loss: 6.9202e-04 - mean_squared_error: 6.9202e-04 - val_loss: 6.9023e-04 - val_mean_squared_error: 6.9023e-04 - 2s/epoch - 92ms/step
# Epoch 174/500
# 26/26 - 2s - loss: 6.6907e-04 - mean_squared_error: 6.6907e-04 - val_loss: 6.7169e-04 - val_mean_squared_error: 6.7169e-04 - 2s/epoch - 65ms/step
# Epoch 175/500
# 26/26 - 1s - loss: 6.5183e-04 - mean_squared_error: 6.5183e-04 - val_loss: 6.5266e-04 - val_mean_squared_error: 6.5266e-04 - 1s/epoch - 49ms/step
# Epoch 176/500
# 26/26 - 1s - loss: 6.3163e-04 - mean_squared_error: 6.3163e-04 - val_loss: 6.3131e-04 - val_mean_squared_error: 6.3131e-04 - 1s/epoch - 44ms/step
# Epoch 177/500
# 26/26 - 1s - loss: 6.1488e-04 - mean_squared_error: 6.1488e-04 - val_loss: 6.1479e-04 - val_mean_squared_error: 6.1479e-04 - 1s/epoch - 45ms/step
# Epoch 178/500
# 26/26 - 1s - loss: 5.9549e-04 - mean_squared_error: 5.9549e-04 - val_loss: 5.9620e-04 - val_mean_squared_error: 5.9620e-04 - 1s/epoch - 45ms/step
# Epoch 179/500
# 26/26 - 1s - loss: 6.5040e-04 - mean_squared_error: 6.5040e-04 - val_loss: 8.1202e-04 - val_mean_squared_error: 8.1202e-04 - 1s/epoch - 50ms/step
# Epoch 180/500
# 26/26 - 1s - loss: 6.5546e-04 - mean_squared_error: 6.5546e-04 - val_loss: 5.9659e-04 - val_mean_squared_error: 5.9659e-04 - 1s/epoch - 51ms/step
# Epoch 181/500
# 26/26 - 1s - loss: 5.7015e-04 - mean_squared_error: 5.7015e-04 - val_loss: 5.6466e-04 - val_mean_squared_error: 5.6466e-04 - 1s/epoch - 45ms/step
# Epoch 182/500
# 26/26 - 3s - loss: 5.4529e-04 - mean_squared_error: 5.4529e-04 - val_loss: 5.5947e-04 - val_mean_squared_error: 5.5947e-04 - 3s/epoch - 109ms/step
# Epoch 183/500
# 26/26 - 3s - loss: 5.3361e-04 - mean_squared_error: 5.3361e-04 - val_loss: 5.2939e-04 - val_mean_squared_error: 5.2939e-04 - 3s/epoch - 122ms/step
# Epoch 184/500
# 26/26 - 3s - loss: 5.1025e-04 - mean_squared_error: 5.1025e-04 - val_loss: 5.0675e-04 - val_mean_squared_error: 5.0675e-04 - 3s/epoch - 110ms/step
# Epoch 185/500
# 26/26 - 3s - loss: 4.8907e-04 - mean_squared_error: 4.8907e-04 - val_loss: 4.9024e-04 - val_mean_squared_error: 4.9024e-04 - 3s/epoch - 110ms/step
# Epoch 186/500
# 26/26 - 3s - loss: 4.7450e-04 - mean_squared_error: 4.7450e-04 - val_loss: 4.7899e-04 - val_mean_squared_error: 4.7899e-04 - 3s/epoch - 113ms/step
# Epoch 187/500
# 26/26 - 4s - loss: 4.6248e-04 - mean_squared_error: 4.6248e-04 - val_loss: 4.6407e-04 - val_mean_squared_error: 4.6407e-04 - 4s/epoch - 171ms/step
# Epoch 188/500
# 26/26 - 3s - loss: 4.4854e-04 - mean_squared_error: 4.4854e-04 - val_loss: 4.5026e-04 - val_mean_squared_error: 4.5026e-04 - 3s/epoch - 100ms/step
# Epoch 189/500
# 26/26 - 3s - loss: 4.3603e-04 - mean_squared_error: 4.3603e-04 - val_loss: 4.3838e-04 - val_mean_squared_error: 4.3838e-04 - 3s/epoch - 133ms/step
# Epoch 190/500
# 26/26 - 3s - loss: 4.2416e-04 - mean_squared_error: 4.2416e-04 - val_loss: 4.2610e-04 - val_mean_squared_error: 4.2610e-04 - 3s/epoch - 99ms/step
# Epoch 191/500
# 26/26 - 4s - loss: 4.1704e-04 - mean_squared_error: 4.1704e-04 - val_loss: 4.1778e-04 - val_mean_squared_error: 4.1778e-04 - 4s/epoch - 135ms/step
# Epoch 192/500
# 26/26 - 3s - loss: 4.1617e-04 - mean_squared_error: 4.1617e-04 - val_loss: 4.4893e-04 - val_mean_squared_error: 4.4893e-04 - 3s/epoch - 104ms/step
# Epoch 193/500
# 26/26 - 1s - loss: 4.1220e-04 - mean_squared_error: 4.1220e-04 - val_loss: 4.0837e-04 - val_mean_squared_error: 4.0837e-04 - 1s/epoch - 55ms/step
# Epoch 194/500
# 26/26 - 1s - loss: 4.5006e-04 - mean_squared_error: 4.5006e-04 - val_loss: 4.0245e-04 - val_mean_squared_error: 4.0245e-04 - 1s/epoch - 45ms/step
# Epoch 195/500
# 26/26 - 1s - loss: 3.9619e-04 - mean_squared_error: 3.9619e-04 - val_loss: 3.8906e-04 - val_mean_squared_error: 3.8906e-04 - 1s/epoch - 44ms/step
# Epoch 196/500
# 26/26 - 1s - loss: 3.7565e-04 - mean_squared_error: 3.7565e-04 - val_loss: 3.9007e-04 - val_mean_squared_error: 3.9007e-04 - 1s/epoch - 44ms/step
# Epoch 197/500
# 26/26 - 1s - loss: 3.5674e-04 - mean_squared_error: 3.5674e-04 - val_loss: 3.5446e-04 - val_mean_squared_error: 3.5446e-04 - 1s/epoch - 45ms/step
# Epoch 198/500
# 26/26 - 1s - loss: 3.4196e-04 - mean_squared_error: 3.4196e-04 - val_loss: 3.4314e-04 - val_mean_squared_error: 3.4314e-04 - 1s/epoch - 44ms/step
# Epoch 199/500
# 26/26 - 1s - loss: 3.3049e-04 - mean_squared_error: 3.3049e-04 - val_loss: 3.3285e-04 - val_mean_squared_error: 3.3285e-04 - 1s/epoch - 50ms/step
# Epoch 200/500
# 26/26 - 2s - loss: 3.2224e-04 - mean_squared_error: 3.2224e-04 - val_loss: 3.2582e-04 - val_mean_squared_error: 3.2582e-04 - 2s/epoch - 63ms/step
# Epoch 201/500
# 26/26 - 2s - loss: 3.1426e-04 - mean_squared_error: 3.1426e-04 - val_loss: 3.1827e-04 - val_mean_squared_error: 3.1827e-04 - 2s/epoch - 85ms/step
# Epoch 202/500
# 26/26 - 1s - loss: 3.1753e-04 - mean_squared_error: 3.1753e-04 - val_loss: 3.1135e-04 - val_mean_squared_error: 3.1135e-04 - 1s/epoch - 50ms/step
# Epoch 203/500
# 26/26 - 1s - loss: 3.1792e-04 - mean_squared_error: 3.1792e-04 - val_loss: 3.1963e-04 - val_mean_squared_error: 3.1963e-04 - 1s/epoch - 44ms/step
# Epoch 204/500
# 26/26 - 1s - loss: 3.7536e-04 - mean_squared_error: 3.7536e-04 - val_loss: 3.6680e-04 - val_mean_squared_error: 3.6680e-04 - 1s/epoch - 44ms/step
# Epoch 205/500
# 26/26 - 1s - loss: 3.3519e-04 - mean_squared_error: 3.3519e-04 - val_loss: 2.9654e-04 - val_mean_squared_error: 2.9654e-04 - 1s/epoch - 44ms/step
# Epoch 206/500
# 26/26 - 1s - loss: 2.8356e-04 - mean_squared_error: 2.8356e-04 - val_loss: 2.8208e-04 - val_mean_squared_error: 2.8208e-04 - 1s/epoch - 44ms/step
# Epoch 207/500
# 26/26 - 1s - loss: 2.6926e-04 - mean_squared_error: 2.6926e-04 - val_loss: 2.6903e-04 - val_mean_squared_error: 2.6903e-04 - 1s/epoch - 44ms/step
# Epoch 208/500
# 26/26 - 1s - loss: 2.5918e-04 - mean_squared_error: 2.5918e-04 - val_loss: 2.6141e-04 - val_mean_squared_error: 2.6141e-04 - 1s/epoch - 44ms/step
# Epoch 209/500
# 26/26 - 1s - loss: 2.5206e-04 - mean_squared_error: 2.5206e-04 - val_loss: 2.5498e-04 - val_mean_squared_error: 2.5498e-04 - 1s/epoch - 44ms/step
# Epoch 210/500
# 26/26 - 1s - loss: 2.4543e-04 - mean_squared_error: 2.4543e-04 - val_loss: 2.4999e-04 - val_mean_squared_error: 2.4999e-04 - 1s/epoch - 49ms/step
# Epoch 211/500
# 26/26 - 2s - loss: 2.4148e-04 - mean_squared_error: 2.4148e-04 - val_loss: 2.4364e-04 - val_mean_squared_error: 2.4364e-04 - 2s/epoch - 85ms/step
# Epoch 212/500
# 26/26 - 2s - loss: 2.4200e-04 - mean_squared_error: 2.4200e-04 - val_loss: 2.4264e-04 - val_mean_squared_error: 2.4264e-04 - 2s/epoch - 64ms/step
# Epoch 213/500
# 26/26 - 1s - loss: 2.3214e-04 - mean_squared_error: 2.3214e-04 - val_loss: 2.3560e-04 - val_mean_squared_error: 2.3560e-04 - 1s/epoch - 44ms/step
# Epoch 214/500
# 26/26 - 1s - loss: 3.7755e-04 - mean_squared_error: 3.7755e-04 - val_loss: 4.0556e-04 - val_mean_squared_error: 4.0556e-04 - 1s/epoch - 50ms/step
# Epoch 215/500
# 26/26 - 1s - loss: 2.7019e-04 - mean_squared_error: 2.7019e-04 - val_loss: 2.3712e-04 - val_mean_squared_error: 2.3712e-04 - 1s/epoch - 44ms/step
# Epoch 216/500
# 26/26 - 1s - loss: 2.1729e-04 - mean_squared_error: 2.1729e-04 - val_loss: 2.1452e-04 - val_mean_squared_error: 2.1452e-04 - 1s/epoch - 45ms/step
# Epoch 217/500
# 26/26 - 1s - loss: 2.0527e-04 - mean_squared_error: 2.0527e-04 - val_loss: 2.0807e-04 - val_mean_squared_error: 2.0807e-04 - 1s/epoch - 44ms/step
# Epoch 218/500
# 26/26 - 1s - loss: 1.9994e-04 - mean_squared_error: 1.9994e-04 - val_loss: 2.0362e-04 - val_mean_squared_error: 2.0362e-04 - 1s/epoch - 44ms/step
# Epoch 219/500
# 26/26 - 1s - loss: 1.9514e-04 - mean_squared_error: 1.9514e-04 - val_loss: 1.9683e-04 - val_mean_squared_error: 1.9683e-04 - 1s/epoch - 44ms/step
# Epoch 220/500
# 26/26 - 1s - loss: 1.8903e-04 - mean_squared_error: 1.8903e-04 - val_loss: 1.9148e-04 - val_mean_squared_error: 1.9148e-04 - 1s/epoch - 44ms/step
# Epoch 221/500
# 26/26 - 2s - loss: 1.8455e-04 - mean_squared_error: 1.8455e-04 - val_loss: 1.8785e-04 - val_mean_squared_error: 1.8785e-04 - 2s/epoch - 82ms/step
# Epoch 222/500
# 26/26 - 2s - loss: 1.7998e-04 - mean_squared_error: 1.7998e-04 - val_loss: 1.8209e-04 - val_mean_squared_error: 1.8209e-04 - 2s/epoch - 73ms/step
# Epoch 223/500
# 26/26 - 1s - loss: 1.7690e-04 - mean_squared_error: 1.7690e-04 - val_loss: 1.7969e-04 - val_mean_squared_error: 1.7969e-04 - 1s/epoch - 44ms/step
# Epoch 224/500
# 26/26 - 1s - loss: 1.7151e-04 - mean_squared_error: 1.7151e-04 - val_loss: 1.8583e-04 - val_mean_squared_error: 1.8583e-04 - 1s/epoch - 44ms/step
# Epoch 225/500
# 26/26 - 1s - loss: 1.9775e-04 - mean_squared_error: 1.9775e-04 - val_loss: 2.5901e-04 - val_mean_squared_error: 2.5901e-04 - 1s/epoch - 50ms/step
# Epoch 226/500
# 26/26 - 1s - loss: 2.8721e-04 - mean_squared_error: 2.8721e-04 - val_loss: 1.9411e-04 - val_mean_squared_error: 1.9411e-04 - 1s/epoch - 44ms/step
# Epoch 227/500
# 26/26 - 1s - loss: 1.8326e-04 - mean_squared_error: 1.8326e-04 - val_loss: 1.9026e-04 - val_mean_squared_error: 1.9026e-04 - 1s/epoch - 44ms/step
# Epoch 228/500
# 26/26 - 1s - loss: 1.6578e-04 - mean_squared_error: 1.6578e-04 - val_loss: 1.6578e-04 - val_mean_squared_error: 1.6578e-04 - 1s/epoch - 44ms/step
# Epoch 229/500
# 26/26 - 1s - loss: 1.6476e-04 - mean_squared_error: 1.6476e-04 - val_loss: 1.6163e-04 - val_mean_squared_error: 1.6163e-04 - 1s/epoch - 44ms/step
# Epoch 230/500
# 26/26 - 1s - loss: 1.5132e-04 - mean_squared_error: 1.5132e-04 - val_loss: 1.4981e-04 - val_mean_squared_error: 1.4981e-04 - 1s/epoch - 45ms/step
# Epoch 231/500
# 26/26 - 2s - loss: 1.4464e-04 - mean_squared_error: 1.4464e-04 - val_loss: 1.5050e-04 - val_mean_squared_error: 1.5050e-04 - 2s/epoch - 73ms/step
# Epoch 232/500
# 26/26 - 2s - loss: 1.4180e-04 - mean_squared_error: 1.4180e-04 - val_loss: 1.4768e-04 - val_mean_squared_error: 1.4768e-04 - 2s/epoch - 81ms/step
# Epoch 233/500
# 26/26 - 1s - loss: 1.3899e-04 - mean_squared_error: 1.3899e-04 - val_loss: 1.3953e-04 - val_mean_squared_error: 1.3953e-04 - 1s/epoch - 45ms/step
# Epoch 234/500
# 26/26 - 1s - loss: 1.3419e-04 - mean_squared_error: 1.3419e-04 - val_loss: 1.3676e-04 - val_mean_squared_error: 1.3676e-04 - 1s/epoch - 45ms/step
# Epoch 235/500
# 26/26 - 1s - loss: 1.3282e-04 - mean_squared_error: 1.3282e-04 - val_loss: 1.3490e-04 - val_mean_squared_error: 1.3490e-04 - 1s/epoch - 51ms/step
# Epoch 236/500
# 26/26 - 1s - loss: 1.3216e-04 - mean_squared_error: 1.3216e-04 - val_loss: 1.3094e-04 - val_mean_squared_error: 1.3094e-04 - 1s/epoch - 44ms/step
# Epoch 237/500
# 26/26 - 1s - loss: 1.4634e-04 - mean_squared_error: 1.4634e-04 - val_loss: 4.5001e-04 - val_mean_squared_error: 4.5001e-04 - 1s/epoch - 51ms/step
# Epoch 238/500
# 26/26 - 1s - loss: 2.5190e-04 - mean_squared_error: 2.5190e-04 - val_loss: 1.4242e-04 - val_mean_squared_error: 1.4242e-04 - 1s/epoch - 45ms/step
# Epoch 239/500
# 26/26 - 1s - loss: 1.6003e-04 - mean_squared_error: 1.6003e-04 - val_loss: 1.7419e-04 - val_mean_squared_error: 1.7419e-04 - 1s/epoch - 45ms/step
# Epoch 240/500
# 26/26 - 1s - loss: 1.3837e-04 - mean_squared_error: 1.3837e-04 - val_loss: 1.2335e-04 - val_mean_squared_error: 1.2335e-04 - 1s/epoch - 44ms/step
# Epoch 241/500
# 26/26 - 2s - loss: 1.1662e-04 - mean_squared_error: 1.1662e-04 - val_loss: 1.1566e-04 - val_mean_squared_error: 1.1566e-04 - 2s/epoch - 74ms/step
# Epoch 242/500
# 26/26 - 2s - loss: 1.1110e-04 - mean_squared_error: 1.1110e-04 - val_loss: 1.1288e-04 - val_mean_squared_error: 1.1288e-04 - 2s/epoch - 84ms/step
# Epoch 243/500
# 26/26 - 1s - loss: 1.0821e-04 - mean_squared_error: 1.0821e-04 - val_loss: 1.1080e-04 - val_mean_squared_error: 1.1080e-04 - 1s/epoch - 44ms/step
# Epoch 244/500
# 26/26 - 1s - loss: 1.0577e-04 - mean_squared_error: 1.0577e-04 - val_loss: 1.0914e-04 - val_mean_squared_error: 1.0914e-04 - 1s/epoch - 44ms/step
# Epoch 245/500
# 26/26 - 1s - loss: 1.0317e-04 - mean_squared_error: 1.0317e-04 - val_loss: 1.0506e-04 - val_mean_squared_error: 1.0506e-04 - 1s/epoch - 44ms/step
# Epoch 246/500
# 26/26 - 1s - loss: 1.0212e-04 - mean_squared_error: 1.0212e-04 - val_loss: 1.0280e-04 - val_mean_squared_error: 1.0280e-04 - 1s/epoch - 44ms/step
# Epoch 247/500
# 26/26 - 1s - loss: 9.9386e-05 - mean_squared_error: 9.9386e-05 - val_loss: 1.0224e-04 - val_mean_squared_error: 1.0224e-04 - 1s/epoch - 44ms/step
# Epoch 248/500
# 26/26 - 1s - loss: 1.0027e-04 - mean_squared_error: 1.0027e-04 - val_loss: 1.0125e-04 - val_mean_squared_error: 1.0125e-04 - 1s/epoch - 44ms/step
# Epoch 249/500
# 26/26 - 1s - loss: 1.0027e-04 - mean_squared_error: 1.0027e-04 - val_loss: 2.4136e-04 - val_mean_squared_error: 2.4136e-04 - 1s/epoch - 44ms/step
# Epoch 250/500
# 26/26 - 1s - loss: 1.8531e-04 - mean_squared_error: 1.8531e-04 - val_loss: 1.2376e-04 - val_mean_squared_error: 1.2376e-04 - 1s/epoch - 43ms/step
# Epoch 251/500
# 26/26 - 2s - loss: 1.0966e-04 - mean_squared_error: 1.0966e-04 - val_loss: 1.0923e-04 - val_mean_squared_error: 1.0923e-04 - 2s/epoch - 63ms/step
# Epoch 252/500
# 26/26 - 2s - loss: 9.5092e-05 - mean_squared_error: 9.5092e-05 - val_loss: 9.0783e-05 - val_mean_squared_error: 9.0783e-05 - 2s/epoch - 85ms/step
# Epoch 253/500
# 26/26 - 1s - loss: 8.6953e-05 - mean_squared_error: 8.6953e-05 - val_loss: 8.8131e-05 - val_mean_squared_error: 8.8131e-05 - 1s/epoch - 49ms/step
# Epoch 254/500
# 26/26 - 1s - loss: 8.4215e-05 - mean_squared_error: 8.4215e-05 - val_loss: 8.7682e-05 - val_mean_squared_error: 8.7682e-05 - 1s/epoch - 44ms/step
# Epoch 255/500
# 26/26 - 1s - loss: 8.5237e-05 - mean_squared_error: 8.5237e-05 - val_loss: 8.5184e-05 - val_mean_squared_error: 8.5184e-05 - 1s/epoch - 45ms/step
# Epoch 256/500
# 26/26 - 1s - loss: 8.0404e-05 - mean_squared_error: 8.0404e-05 - val_loss: 8.1512e-05 - val_mean_squared_error: 8.1512e-05 - 1s/epoch - 44ms/step
# Epoch 257/500
# 26/26 - 1s - loss: 7.8432e-05 - mean_squared_error: 7.8432e-05 - val_loss: 8.1607e-05 - val_mean_squared_error: 8.1607e-05 - 1s/epoch - 44ms/step
# Epoch 258/500
# 26/26 - 1s - loss: 1.2893e-04 - mean_squared_error: 1.2893e-04 - val_loss: 1.5524e-04 - val_mean_squared_error: 1.5524e-04 - 1s/epoch - 44ms/step
# Epoch 259/500
# 26/26 - 1s - loss: 9.9609e-05 - mean_squared_error: 9.9609e-05 - val_loss: 8.4597e-05 - val_mean_squared_error: 8.4597e-05 - 1s/epoch - 44ms/step
# Epoch 260/500
# 26/26 - 1s - loss: 7.8910e-05 - mean_squared_error: 7.8910e-05 - val_loss: 7.9150e-05 - val_mean_squared_error: 7.9150e-05 - 1s/epoch - 44ms/step
# Epoch 261/500
# 26/26 - 1s - loss: 7.3424e-05 - mean_squared_error: 7.3424e-05 - val_loss: 7.4481e-05 - val_mean_squared_error: 7.4481e-05 - 1s/epoch - 49ms/step
# Epoch 262/500
# 26/26 - 2s - loss: 7.3433e-05 - mean_squared_error: 7.3433e-05 - val_loss: 8.4280e-05 - val_mean_squared_error: 8.4280e-05 - 2s/epoch - 83ms/step
# Epoch 263/500
# 26/26 - 2s - loss: 7.3158e-05 - mean_squared_error: 7.3158e-05 - val_loss: 7.1193e-05 - val_mean_squared_error: 7.1193e-05 - 2s/epoch - 66ms/step
# Epoch 264/500
# 26/26 - 1s - loss: 7.9044e-05 - mean_squared_error: 7.9044e-05 - val_loss: 1.0268e-04 - val_mean_squared_error: 1.0268e-04 - 1s/epoch - 44ms/step
# Epoch 265/500
# 26/26 - 1s - loss: 1.3272e-04 - mean_squared_error: 1.3272e-04 - val_loss: 1.5596e-04 - val_mean_squared_error: 1.5596e-04 - 1s/epoch - 44ms/step
# Epoch 266/500
# 26/26 - 1s - loss: 1.2529e-04 - mean_squared_error: 1.2529e-04 - val_loss: 9.3747e-05 - val_mean_squared_error: 9.3747e-05 - 1s/epoch - 44ms/step
# Epoch 267/500
# 26/26 - 1s - loss: 7.1201e-05 - mean_squared_error: 7.1201e-05 - val_loss: 6.9923e-05 - val_mean_squared_error: 6.9923e-05 - 1s/epoch - 44ms/step
# Epoch 268/500
# 26/26 - 1s - loss: 7.5739e-05 - mean_squared_error: 7.5739e-05 - val_loss: 6.7506e-05 - val_mean_squared_error: 6.7506e-05 - 1s/epoch - 50ms/step
# Epoch 269/500
# 26/26 - 1s - loss: 7.0393e-05 - mean_squared_error: 7.0393e-05 - val_loss: 9.4580e-05 - val_mean_squared_error: 9.4580e-05 - 1s/epoch - 44ms/step
# Epoch 270/500
# 26/26 - 1s - loss: 6.4701e-05 - mean_squared_error: 6.4701e-05 - val_loss: 6.1692e-05 - val_mean_squared_error: 6.1692e-05 - 1s/epoch - 44ms/step
# Epoch 271/500
# 26/26 - 1s - loss: 5.8579e-05 - mean_squared_error: 5.8579e-05 - val_loss: 6.0107e-05 - val_mean_squared_error: 6.0107e-05 - 1s/epoch - 44ms/step
# Epoch 272/500
# 26/26 - 2s - loss: 6.0091e-05 - mean_squared_error: 6.0091e-05 - val_loss: 6.0878e-05 - val_mean_squared_error: 6.0878e-05 - 2s/epoch - 82ms/step
# Epoch 273/500
# 26/26 - 2s - loss: 5.6658e-05 - mean_squared_error: 5.6658e-05 - val_loss: 7.1089e-05 - val_mean_squared_error: 7.1089e-05 - 2s/epoch - 73ms/step
# Epoch 274/500
# 26/26 - 1s - loss: 9.1571e-05 - mean_squared_error: 9.1571e-05 - val_loss: 6.8066e-05 - val_mean_squared_error: 6.8066e-05 - 1s/epoch - 51ms/step
# Epoch 275/500
# 26/26 - 1s - loss: 6.4429e-05 - mean_squared_error: 6.4429e-05 - val_loss: 7.0604e-05 - val_mean_squared_error: 7.0604e-05 - 1s/epoch - 44ms/step
# Epoch 276/500
# 26/26 - 1s - loss: 6.9180e-05 - mean_squared_error: 6.9180e-05 - val_loss: 9.3368e-05 - val_mean_squared_error: 9.3368e-05 - 1s/epoch - 44ms/step
# Epoch 277/500
# 26/26 - 1s - loss: 1.4871e-04 - mean_squared_error: 1.4871e-04 - val_loss: 1.9302e-04 - val_mean_squared_error: 1.9302e-04 - 1s/epoch - 51ms/step
# Epoch 278/500
# 26/26 - 1s - loss: 1.0371e-04 - mean_squared_error: 1.0371e-04 - val_loss: 7.2544e-05 - val_mean_squared_error: 7.2544e-05 - 1s/epoch - 44ms/step
# Epoch 279/500
# 26/26 - 1s - loss: 5.5551e-05 - mean_squared_error: 5.5551e-05 - val_loss: 5.6986e-05 - val_mean_squared_error: 5.6986e-05 - 1s/epoch - 44ms/step
# Epoch 280/500
# 26/26 - 1s - loss: 5.3039e-05 - mean_squared_error: 5.3039e-05 - val_loss: 5.0364e-05 - val_mean_squared_error: 5.0364e-05 - 1s/epoch - 44ms/step
# Epoch 281/500
# 26/26 - 1s - loss: 4.8769e-05 - mean_squared_error: 4.8769e-05 - val_loss: 4.9845e-05 - val_mean_squared_error: 4.9845e-05 - 1s/epoch - 44ms/step
# Epoch 282/500
# 26/26 - 2s - loss: 4.7565e-05 - mean_squared_error: 4.7565e-05 - val_loss: 4.8162e-05 - val_mean_squared_error: 4.8162e-05 - 2s/epoch - 80ms/step
# Epoch 283/500
# 26/26 - 2s - loss: 4.7001e-05 - mean_squared_error: 4.7001e-05 - val_loss: 4.7829e-05 - val_mean_squared_error: 4.7829e-05 - 2s/epoch - 77ms/step
# Epoch 284/500
# 26/26 - 1s - loss: 4.5736e-05 - mean_squared_error: 4.5736e-05 - val_loss: 4.5650e-05 - val_mean_squared_error: 4.5650e-05 - 1s/epoch - 44ms/step
# Epoch 285/500
# 26/26 - 1s - loss: 4.6715e-05 - mean_squared_error: 4.6715e-05 - val_loss: 6.0557e-05 - val_mean_squared_error: 6.0557e-05 - 1s/epoch - 44ms/step
# Epoch 286/500
# 26/26 - 1s - loss: 5.2797e-05 - mean_squared_error: 5.2797e-05 - val_loss: 4.4460e-05 - val_mean_squared_error: 4.4460e-05 - 1s/epoch - 45ms/step
# Epoch 287/500
# 26/26 - 1s - loss: 4.3801e-05 - mean_squared_error: 4.3801e-05 - val_loss: 4.4823e-05 - val_mean_squared_error: 4.4823e-05 - 1s/epoch - 45ms/step
# Epoch 288/500
# 26/26 - 1s - loss: 7.3970e-05 - mean_squared_error: 7.3970e-05 - val_loss: 1.2125e-04 - val_mean_squared_error: 1.2125e-04 - 1s/epoch - 44ms/step
# Epoch 289/500
# 26/26 - 1s - loss: 1.0497e-04 - mean_squared_error: 1.0497e-04 - val_loss: 7.6698e-05 - val_mean_squared_error: 7.6698e-05 - 1s/epoch - 44ms/step
# Epoch 290/500
# 26/26 - 1s - loss: 7.5944e-05 - mean_squared_error: 7.5944e-05 - val_loss: 4.8898e-05 - val_mean_squared_error: 4.8898e-05 - 1s/epoch - 45ms/step
# Epoch 291/500
# 26/26 - 1s - loss: 4.3047e-05 - mean_squared_error: 4.3047e-05 - val_loss: 4.1279e-05 - val_mean_squared_error: 4.1279e-05 - 1s/epoch - 44ms/step
# Epoch 292/500
# 26/26 - 2s - loss: 3.9440e-05 - mean_squared_error: 3.9440e-05 - val_loss: 4.2346e-05 - val_mean_squared_error: 4.2346e-05 - 2s/epoch - 67ms/step
# Epoch 293/500
# 26/26 - 2s - loss: 3.8302e-05 - mean_squared_error: 3.8302e-05 - val_loss: 3.8847e-05 - val_mean_squared_error: 3.8847e-05 - 2s/epoch - 85ms/step
# Epoch 294/500
# 26/26 - 1s - loss: 3.7325e-05 - mean_squared_error: 3.7325e-05 - val_loss: 3.9018e-05 - val_mean_squared_error: 3.9018e-05 - 1s/epoch - 46ms/step
# Epoch 295/500
# 26/26 - 1s - loss: 3.8941e-05 - mean_squared_error: 3.8941e-05 - val_loss: 4.0386e-05 - val_mean_squared_error: 4.0386e-05 - 1s/epoch - 44ms/step
# Epoch 296/500
# 26/26 - 1s - loss: 8.7089e-05 - mean_squared_error: 8.7089e-05 - val_loss: 6.5395e-05 - val_mean_squared_error: 6.5395e-05 - 1s/epoch - 44ms/step
# Epoch 297/500
# 26/26 - 1s - loss: 5.5663e-05 - mean_squared_error: 5.5663e-05 - val_loss: 5.0082e-05 - val_mean_squared_error: 5.0082e-05 - 1s/epoch - 44ms/step
# Epoch 298/500
# 26/26 - 1s - loss: 4.7290e-05 - mean_squared_error: 4.7290e-05 - val_loss: 3.9643e-05 - val_mean_squared_error: 3.9643e-05 - 1s/epoch - 44ms/step
# Epoch 299/500
# 26/26 - 1s - loss: 3.7829e-05 - mean_squared_error: 3.7829e-05 - val_loss: 3.4121e-05 - val_mean_squared_error: 3.4121e-05 - 1s/epoch - 50ms/step
# Epoch 300/500
# 26/26 - 1s - loss: 3.6519e-05 - mean_squared_error: 3.6519e-05 - val_loss: 4.7316e-05 - val_mean_squared_error: 4.7316e-05 - 1s/epoch - 44ms/step
# Epoch 301/500
# 26/26 - 1s - loss: 1.0945e-04 - mean_squared_error: 1.0945e-04 - val_loss: 1.8507e-04 - val_mean_squared_error: 1.8507e-04 - 1s/epoch - 44ms/step
# Epoch 302/500
# 26/26 - 1s - loss: 1.3172e-04 - mean_squared_error: 1.3172e-04 - val_loss: 7.0712e-05 - val_mean_squared_error: 7.0712e-05 - 1s/epoch - 56ms/step
# Epoch 303/500
# 26/26 - 2s - loss: 4.1619e-05 - mean_squared_error: 4.1619e-05 - val_loss: 3.7341e-05 - val_mean_squared_error: 3.7341e-05 - 2s/epoch - 82ms/step
# Epoch 304/500
# 26/26 - 2s - loss: 3.4242e-05 - mean_squared_error: 3.4242e-05 - val_loss: 3.4434e-05 - val_mean_squared_error: 3.4434e-05 - 2s/epoch - 59ms/step
# Epoch 305/500
# 26/26 - 1s - loss: 3.3226e-05 - mean_squared_error: 3.3226e-05 - val_loss: 3.2196e-05 - val_mean_squared_error: 3.2196e-05 - 1s/epoch - 45ms/step
# Epoch 306/500
# 26/26 - 1s - loss: 3.1044e-05 - mean_squared_error: 3.1044e-05 - val_loss: 3.1719e-05 - val_mean_squared_error: 3.1719e-05 - 1s/epoch - 44ms/step
# Epoch 307/500
# 26/26 - 1s - loss: 3.0041e-05 - mean_squared_error: 3.0041e-05 - val_loss: 2.9643e-05 - val_mean_squared_error: 2.9643e-05 - 1s/epoch - 43ms/step
# Epoch 308/500
# 26/26 - 1s - loss: 2.8429e-05 - mean_squared_error: 2.8429e-05 - val_loss: 2.9375e-05 - val_mean_squared_error: 2.9375e-05 - 1s/epoch - 44ms/step
# Epoch 309/500
# 26/26 - 1s - loss: 2.8458e-05 - mean_squared_error: 2.8458e-05 - val_loss: 2.9905e-05 - val_mean_squared_error: 2.9905e-05 - 1s/epoch - 44ms/step
# Epoch 310/500
# 26/26 - 1s - loss: 2.9209e-05 - mean_squared_error: 2.9209e-05 - val_loss: 2.8165e-05 - val_mean_squared_error: 2.8165e-05 - 1s/epoch - 50ms/step
# Epoch 311/500
# 26/26 - 1s - loss: 5.1681e-05 - mean_squared_error: 5.1681e-05 - val_loss: 3.7867e-05 - val_mean_squared_error: 3.7867e-05 - 1s/epoch - 44ms/step
# Epoch 312/500
# 26/26 - 1s - loss: 7.1187e-05 - mean_squared_error: 7.1187e-05 - val_loss: 6.9345e-05 - val_mean_squared_error: 6.9345e-05 - 1s/epoch - 46ms/step
# Epoch 313/500
# 26/26 - 2s - loss: 6.2520e-05 - mean_squared_error: 6.2520e-05 - val_loss: 7.3678e-05 - val_mean_squared_error: 7.3678e-05 - 2s/epoch - 85ms/step
# Epoch 314/500
# 26/26 - 2s - loss: 4.7102e-05 - mean_squared_error: 4.7102e-05 - val_loss: 3.0220e-05 - val_mean_squared_error: 3.0220e-05 - 2s/epoch - 68ms/step
# Epoch 315/500
# 26/26 - 1s - loss: 2.9010e-05 - mean_squared_error: 2.9010e-05 - val_loss: 2.5710e-05 - val_mean_squared_error: 2.5710e-05 - 1s/epoch - 44ms/step
# Epoch 316/500
# 26/26 - 1s - loss: 2.6234e-05 - mean_squared_error: 2.6234e-05 - val_loss: 3.3042e-05 - val_mean_squared_error: 3.3042e-05 - 1s/epoch - 44ms/step
# Epoch 317/500
# ...
# Epoch 415/500
# 26/26 - 1s - loss: 6.8887e-06 - mean_squared_error: 6.8887e-06 - val_loss: 8.7105e-06 - val_mean_squared_error: 8.7105e-06 - 1s/epoch - 48ms/step
# Epoch 416/500
# 26/26 - 1s - loss: 9.2032e-06 - mean_squared_error: 9.2032e-06 - val_loss: 6.7109e-06 - val_mean_squared_error: 6.7109e-06 - 1s/epoch - 44ms/step
# Epoch 417/500
# 26/26 - 1s - loss: 7.8476e-06 - mean_squared_error: 7.8476e-06 - val_loss: 1.4108e-05 - val_mean_squared_error: 1.4108e-05 - 1s/epoch - 44ms/step
# Epoch 418/500
# 26/26 - 1s - loss: 8.5745e-05 - mean_squared_error: 8.5745e-05 - val_loss: 3.0182e-05 - val_mean_squared_error: 3.0182e-05 - 1s/epoch - 44ms/step
# Epoch 419/500
# 26/26 - 1s - loss: 3.4994e-05 - mean_squared_error: 3.4994e-05 - val_loss: 9.0619e-05 - val_mean_squared_error: 9.0619e-05 - 1s/epoch - 44ms/step
# Epoch 420/500
# 26/26 - 1s - loss: 1.7341e-05 - mean_squared_error: 1.7341e-05 - val_loss: 6.6173e-06 - val_mean_squared_error: 6.6173e-06 - 1s/epoch - 50ms/step
# Epoch 421/500
# 26/26 - 1s - loss: 8.1583e-06 - mean_squared_error: 8.1583e-06 - val_loss: 1.2904e-05 - val_mean_squared_error: 1.2904e-05 - 1s/epoch - 45ms/step
# Epoch 422/500
# 26/26 - 1s - loss: 1.0573e-05 - mean_squared_error: 1.0573e-05 - val_loss: 6.7226e-06 - val_mean_squared_error: 6.7226e-06 - 1s/epoch - 45ms/step
# Epoch 423/500
# 26/26 - 2s - loss: 6.4009e-06 - mean_squared_error: 6.4009e-06 - val_loss: 7.7845e-06 - val_mean_squared_error: 7.7845e-06 - 2s/epoch - 61ms/step
# Epoch 424/500
# 26/26 - 2s - loss: 6.4916e-06 - mean_squared_error: 6.4916e-06 - val_loss: 7.1910e-06 - val_mean_squared_error: 7.1910e-06 - 2s/epoch - 85ms/step
# Epoch 425/500
# 26/26 - 1s - loss: 6.8545e-06 - mean_squared_error: 6.8545e-06 - val_loss: 1.0169e-05 - val_mean_squared_error: 1.0169e-05 - 1s/epoch - 53ms/step
# Epoch 426/500
# 26/26 - 1s - loss: 7.1612e-05 - mean_squared_error: 7.1612e-05 - val_loss: 4.0284e-04 - val_mean_squared_error: 4.0284e-04 - 1s/epoch - 44ms/step
# Epoch 427/500
# 26/26 - 1s - loss: 1.3868e-04 - mean_squared_error: 1.3868e-04 - val_loss: 7.7909e-05 - val_mean_squared_error: 7.7909e-05 - 1s/epoch - 44ms/step
# Epoch 428/500
# 26/26 - 1s - loss: 3.1772e-05 - mean_squared_error: 3.1772e-05 - val_loss: 5.2612e-05 - val_mean_squared_error: 5.2612e-05 - 1s/epoch - 44ms/step
# Epoch 429/500
# 26/26 - 1s - loss: 2.0235e-05 - mean_squared_error: 2.0235e-05 - val_loss: 1.5325e-05 - val_mean_squared_error: 1.5325e-05 - 1s/epoch - 44ms/step
# Epoch 430/500
# 26/26 - 1s - loss: 8.7288e-06 - mean_squared_error: 8.7288e-06 - val_loss: 6.0472e-06 - val_mean_squared_error: 6.0472e-06 - 1s/epoch - 45ms/step
# Epoch 431/500
# 26/26 - 1s - loss: 5.6478e-06 - mean_squared_error: 5.6478e-06 - val_loss: 5.6334e-06 - val_mean_squared_error: 5.6334e-06 - 1s/epoch - 50ms/step
# Epoch 432/500
# 26/26 - 1s - loss: 5.5134e-06 - mean_squared_error: 5.5134e-06 - val_loss: 5.6878e-06 - val_mean_squared_error: 5.6878e-06 - 1s/epoch - 44ms/step
# Epoch 433/500
# 26/26 - 1s - loss: 5.3031e-06 - mean_squared_error: 5.3031e-06 - val_loss: 5.4880e-06 - val_mean_squared_error: 5.4880e-06 - 1s/epoch - 53ms/step
# Epoch 434/500
# 26/26 - 2s - loss: 5.2603e-06 - mean_squared_error: 5.2603e-06 - val_loss: 5.3899e-06 - val_mean_squared_error: 5.3899e-06 - 2s/epoch - 83ms/step
# Epoch 435/500
# 26/26 - 2s - loss: 5.2578e-06 - mean_squared_error: 5.2578e-06 - val_loss: 5.2098e-06 - val_mean_squared_error: 5.2098e-06 - 2s/epoch - 62ms/step
# Epoch 436/500
# 26/26 - 1s - loss: 5.1596e-06 - mean_squared_error: 5.1596e-06 - val_loss: 5.1800e-06 - val_mean_squared_error: 5.1800e-06 - 1s/epoch - 44ms/step
# Epoch 437/500
# 26/26 - 1s - loss: 5.5400e-06 - mean_squared_error: 5.5400e-06 - val_loss: 5.3966e-06 - val_mean_squared_error: 5.3966e-06 - 1s/epoch - 44ms/step
# Epoch 438/500
# 26/26 - 1s - loss: 5.9087e-06 - mean_squared_error: 5.9087e-06 - val_loss: 5.7173e-06 - val_mean_squared_error: 5.7173e-06 - 1s/epoch - 44ms/step
# Epoch 439/500
# 26/26 - 1s - loss: 5.3924e-06 - mean_squared_error: 5.3924e-06 - val_loss: 7.1349e-06 - val_mean_squared_error: 7.1349e-06 - 1s/epoch - 44ms/step
# Epoch 440/500
# 26/26 - 1s - loss: 7.9565e-05 - mean_squared_error: 7.9565e-05 - val_loss: 1.4508e-04 - val_mean_squared_error: 1.4508e-04 - 1s/epoch - 45ms/step
# Epoch 441/500
# 26/26 - 1s - loss: 6.6917e-05 - mean_squared_error: 6.6917e-05 - val_loss: 3.2636e-05 - val_mean_squared_error: 3.2636e-05 - 1s/epoch - 45ms/step
# Epoch 442/500
# 26/26 - 1s - loss: 2.6205e-05 - mean_squared_error: 2.6205e-05 - val_loss: 2.0663e-05 - val_mean_squared_error: 2.0663e-05 - 1s/epoch - 44ms/step
# Epoch 443/500
# 26/26 - 1s - loss: 7.9113e-06 - mean_squared_error: 7.9113e-06 - val_loss: 7.5550e-06 - val_mean_squared_error: 7.5550e-06 - 1s/epoch - 44ms/step
# Epoch 444/500
# 26/26 - 2s - loss: 6.2035e-06 - mean_squared_error: 6.2035e-06 - val_loss: 5.2983e-06 - val_mean_squared_error: 5.2983e-06 - 2s/epoch - 83ms/step
# Epoch 445/500
# 26/26 - 2s - loss: 4.9366e-06 - mean_squared_error: 4.9366e-06 - val_loss: 6.5481e-06 - val_mean_squared_error: 6.5481e-06 - 2s/epoch - 73ms/step
# Epoch 446/500
# 26/26 - 1s - loss: 6.4486e-06 - mean_squared_error: 6.4486e-06 - val_loss: 6.1106e-06 - val_mean_squared_error: 6.1106e-06 - 1s/epoch - 45ms/step
# Epoch 447/500
# 26/26 - 1s - loss: 6.5969e-06 - mean_squared_error: 6.5969e-06 - val_loss: 8.5875e-06 - val_mean_squared_error: 8.5875e-06 - 1s/epoch - 44ms/step
# Epoch 448/500
# 26/26 - 1s - loss: 5.7160e-06 - mean_squared_error: 5.7160e-06 - val_loss: 5.0690e-06 - val_mean_squared_error: 5.0690e-06 - 1s/epoch - 44ms/step
# Epoch 449/500
# 26/26 - 1s - loss: 8.7309e-06 - mean_squared_error: 8.7309e-06 - val_loss: 4.0596e-05 - val_mean_squared_error: 4.0596e-05 - 1s/epoch - 45ms/step
# Epoch 450/500
# 26/26 - 1s - loss: 6.9445e-05 - mean_squared_error: 6.9445e-05 - val_loss: 3.0844e-05 - val_mean_squared_error: 3.0844e-05 - 1s/epoch - 45ms/step
# Epoch 451/500
# 26/26 - 1s - loss: 1.3461e-05 - mean_squared_error: 1.3461e-05 - val_loss: 8.5818e-06 - val_mean_squared_error: 8.5818e-06 - 1s/epoch - 51ms/step
# Epoch 452/500
# 26/26 - 1s - loss: 6.9050e-06 - mean_squared_error: 6.9050e-06 - val_loss: 5.0203e-06 - val_mean_squared_error: 5.0203e-06 - 1s/epoch - 44ms/step
# Epoch 453/500
# 26/26 - 1s - loss: 5.2567e-06 - mean_squared_error: 5.2567e-06 - val_loss: 5.6570e-06 - val_mean_squared_error: 5.6570e-06 - 1s/epoch - 45ms/step
# Epoch 454/500
# 26/26 - 2s - loss: 5.5268e-06 - mean_squared_error: 5.5268e-06 - val_loss: 7.4333e-06 - val_mean_squared_error: 7.4333e-06 - 2s/epoch - 77ms/step
# Epoch 455/500
# 26/26 - 2s - loss: 5.7896e-06 - mean_squared_error: 5.7896e-06 - val_loss: 5.5878e-06 - val_mean_squared_error: 5.5878e-06 - 2s/epoch - 79ms/step
# Epoch 456/500
# 26/26 - 1s - loss: 1.2039e-04 - mean_squared_error: 1.2039e-04 - val_loss: 1.5193e-04 - val_mean_squared_error: 1.5193e-04 - 1s/epoch - 44ms/step
# Epoch 457/500
# 26/26 - 1s - loss: 8.0413e-05 - mean_squared_error: 8.0413e-05 - val_loss: 4.8672e-05 - val_mean_squared_error: 4.8672e-05 - 1s/epoch - 44ms/step
# Epoch 458/500
# 26/26 - 1s - loss: 5.0192e-05 - mean_squared_error: 5.0192e-05 - val_loss: 1.5039e-05 - val_mean_squared_error: 1.5039e-05 - 1s/epoch - 45ms/step
# Epoch 459/500
# 26/26 - 1s - loss: 1.2319e-05 - mean_squared_error: 1.2319e-05 - val_loss: 5.5742e-06 - val_mean_squared_error: 5.5742e-06 - 1s/epoch - 45ms/step
# Epoch 460/500
# 26/26 - 1s - loss: 4.5598e-06 - mean_squared_error: 4.5598e-06 - val_loss: 4.4258e-06 - val_mean_squared_error: 4.4258e-06 - 1s/epoch - 45ms/step
# Epoch 461/500
# 26/26 - 1s - loss: 4.2208e-06 - mean_squared_error: 4.2208e-06 - val_loss: 4.5698e-06 - val_mean_squared_error: 4.5698e-06 - 1s/epoch - 50ms/step
# Epoch 462/500
# 26/26 - 1s - loss: 4.2095e-06 - mean_squared_error: 4.2095e-06 - val_loss: 4.3623e-06 - val_mean_squared_error: 4.3623e-06 - 1s/epoch - 45ms/step
# Epoch 463/500
# 26/26 - 1s - loss: 4.0794e-06 - mean_squared_error: 4.0794e-06 - val_loss: 4.5009e-06 - val_mean_squared_error: 4.5009e-06 - 1s/epoch - 50ms/step
# Epoch 464/500
# 26/26 - 2s - loss: 4.1207e-06 - mean_squared_error: 4.1207e-06 - val_loss: 4.2342e-06 - val_mean_squared_error: 4.2342e-06 - 2s/epoch - 76ms/step
# Epoch 465/500
# 26/26 - 2s - loss: 4.1545e-06 - mean_squared_error: 4.1545e-06 - val_loss: 4.3132e-06 - val_mean_squared_error: 4.3132e-06 - 2s/epoch - 80ms/step
# Epoch 466/500
# 26/26 - 1s - loss: 4.0894e-06 - mean_squared_error: 4.0894e-06 - val_loss: 4.3463e-06 - val_mean_squared_error: 4.3463e-06 - 1s/epoch - 44ms/step
# Epoch 467/500
# 26/26 - 1s - loss: 4.0617e-06 - mean_squared_error: 4.0617e-06 - val_loss: 4.3401e-06 - val_mean_squared_error: 4.3401e-06 - 1s/epoch - 44ms/step
# Epoch 468/500
# 26/26 - 1s - loss: 6.1719e-06 - mean_squared_error: 6.1719e-06 - val_loss: 1.1847e-05 - val_mean_squared_error: 1.1847e-05 - 1s/epoch - 44ms/step
# Epoch 469/500
# 26/26 - 1s - loss: 5.7233e-06 - mean_squared_error: 5.7233e-06 - val_loss: 9.0843e-06 - val_mean_squared_error: 9.0843e-06 - 1s/epoch - 45ms/step
# Epoch 470/500
# 26/26 - 1s - loss: 4.0458e-05 - mean_squared_error: 4.0458e-05 - val_loss: 5.0756e-04 - val_mean_squared_error: 5.0756e-04 - 1s/epoch - 50ms/step
# Epoch 471/500
# 26/26 - 1s - loss: 1.3277e-04 - mean_squared_error: 1.3277e-04 - val_loss: 1.9500e-05 - val_mean_squared_error: 1.9500e-05 - 1s/epoch - 44ms/step
# Epoch 472/500
# 26/26 - 1s - loss: 1.3189e-05 - mean_squared_error: 1.3189e-05 - val_loss: 6.7939e-06 - val_mean_squared_error: 6.7939e-06 - 1s/epoch - 44ms/step
# Epoch 473/500
# 26/26 - 1s - loss: 5.1792e-06 - mean_squared_error: 5.1792e-06 - val_loss: 7.7581e-06 - val_mean_squared_error: 7.7581e-06 - 1s/epoch - 44ms/step
# Epoch 474/500
# 26/26 - 2s - loss: 5.1344e-06 - mean_squared_error: 5.1344e-06 - val_loss: 4.1897e-06 - val_mean_squared_error: 4.1897e-06 - 2s/epoch - 70ms/step
# Epoch 475/500
# 26/26 - 2s - loss: 3.9789e-06 - mean_squared_error: 3.9789e-06 - val_loss: 4.1770e-06 - val_mean_squared_error: 4.1770e-06 - 2s/epoch - 84ms/step
# Epoch 476/500
# 26/26 - 1s - loss: 3.8488e-06 - mean_squared_error: 3.8488e-06 - val_loss: 4.0352e-06 - val_mean_squared_error: 4.0352e-06 - 1s/epoch - 45ms/step
# Epoch 477/500
# 26/26 - 1s - loss: 3.9238e-06 - mean_squared_error: 3.9238e-06 - val_loss: 5.9098e-06 - val_mean_squared_error: 5.9098e-06 - 1s/epoch - 44ms/step
# Epoch 478/500
# 26/26 - 1s - loss: 7.2046e-06 - mean_squared_error: 7.2046e-06 - val_loss: 1.0103e-05 - val_mean_squared_error: 1.0103e-05 - 1s/epoch - 45ms/step
# Epoch 479/500
# 26/26 - 1s - loss: 4.6141e-06 - mean_squared_error: 4.6141e-06 - val_loss: 3.9362e-06 - val_mean_squared_error: 3.9362e-06 - 1s/epoch - 44ms/step
# Epoch 480/500
# 26/26 - 1s - loss: 4.5007e-06 - mean_squared_error: 4.5007e-06 - val_loss: 3.8292e-06 - val_mean_squared_error: 3.8292e-06 - 1s/epoch - 45ms/step
# Epoch 481/500
# 26/26 - 1s - loss: 3.7059e-06 - mean_squared_error: 3.7059e-06 - val_loss: 4.0028e-06 - val_mean_squared_error: 4.0028e-06 - 1s/epoch - 44ms/step
# Epoch 482/500
# 26/26 - 1s - loss: 6.3635e-05 - mean_squared_error: 6.3635e-05 - val_loss: 1.4164e-04 - val_mean_squared_error: 1.4164e-04 - 1s/epoch - 45ms/step
# Epoch 483/500
# 26/26 - 1s - loss: 1.1578e-04 - mean_squared_error: 1.1578e-04 - val_loss: 1.1245e-04 - val_mean_squared_error: 1.1245e-04 - 1s/epoch - 45ms/step
# Epoch 484/500
# 26/26 - 2s - loss: 4.1143e-05 - mean_squared_error: 4.1143e-05 - val_loss: 1.3391e-05 - val_mean_squared_error: 1.3391e-05 - 2s/epoch - 62ms/step
# Epoch 485/500
# 26/26 - 2s - loss: 7.6676e-06 - mean_squared_error: 7.6676e-06 - val_loss: 5.4561e-06 - val_mean_squared_error: 5.4561e-06 - 2s/epoch - 85ms/step
# Epoch 486/500
# 26/26 - 1s - loss: 3.8668e-06 - mean_squared_error: 3.8668e-06 - val_loss: 3.6390e-06 - val_mean_squared_error: 3.6390e-06 - 1s/epoch - 53ms/step
# Epoch 487/500
# 26/26 - 1s - loss: 3.6666e-06 - mean_squared_error: 3.6666e-06 - val_loss: 3.6205e-06 - val_mean_squared_error: 3.6205e-06 - 1s/epoch - 45ms/step
# Epoch 488/500
# 26/26 - 1s - loss: 3.5287e-06 - mean_squared_error: 3.5287e-06 - val_loss: 3.7846e-06 - val_mean_squared_error: 3.7846e-06 - 1s/epoch - 44ms/step
# Epoch 489/500
# 26/26 - 1s - loss: 3.5891e-06 - mean_squared_error: 3.5891e-06 - val_loss: 3.7504e-06 - val_mean_squared_error: 3.7504e-06 - 1s/epoch - 45ms/step
# Epoch 490/500
# 26/26 - 1s - loss: 3.6411e-06 - mean_squared_error: 3.6411e-06 - val_loss: 4.1202e-06 - val_mean_squared_error: 4.1202e-06 - 1s/epoch - 45ms/step
# Epoch 491/500
# 26/26 - 1s - loss: 5.9699e-06 - mean_squared_error: 5.9699e-06 - val_loss: 5.5662e-06 - val_mean_squared_error: 5.5662e-06 - 1s/epoch - 52ms/step
# Epoch 492/500
# 26/26 - 1s - loss: 4.8450e-06 - mean_squared_error: 4.8450e-06 - val_loss: 5.5837e-06 - val_mean_squared_error: 5.5837e-06 - 1s/epoch - 44ms/step
# Epoch 493/500
# 26/26 - 1s - loss: 6.8831e-05 - mean_squared_error: 6.8831e-05 - val_loss: 1.9391e-05 - val_mean_squared_error: 1.9391e-05 - 1s/epoch - 45ms/step
# Epoch 494/500
# 26/26 - 2s - loss: 1.5627e-05 - mean_squared_error: 1.5627e-05 - val_loss: 1.0077e-05 - val_mean_squared_error: 1.0077e-05 - 2s/epoch - 58ms/step
# Epoch 495/500
# 26/26 - 2s - loss: 4.3429e-06 - mean_squared_error: 4.3429e-06 - val_loss: 4.5792e-06 - val_mean_squared_error: 4.5792e-06 - 2s/epoch - 84ms/step
# Epoch 496/500
# 26/26 - 2s - loss: 3.9889e-06 - mean_squared_error: 3.9889e-06 - val_loss: 3.4163e-06 - val_mean_squared_error: 3.4163e-06 - 2s/epoch - 62ms/step
# Epoch 497/500
# 26/26 - 1s - loss: 3.7732e-06 - mean_squared_error: 3.7732e-06 - val_loss: 3.7135e-06 - val_mean_squared_error: 3.7135e-06 - 1s/epoch - 51ms/step
# Epoch 498/500
# 26/26 - 1s - loss: 4.0916e-06 - mean_squared_error: 4.0916e-06 - val_loss: 3.4698e-06 - val_mean_squared_error: 3.4698e-06 - 1s/epoch - 45ms/step
# Epoch 499/500
# 26/26 - 1s - loss: 1.6753e-05 - mean_squared_error: 1.6753e-05 - val_loss: 2.2659e-04 - val_mean_squared_error: 2.2659e-04 - 1s/epoch - 50ms/step
# Epoch 500/500
# 26/26 - 1s - loss: 1.2921e-04 - mean_squared_error: 1.2921e-04 - val_loss: 2.7809e-05 - val_mean_squared_error: 2.7809e-05 - 1s/epoch - 45ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10, 8)]              0         []
#
#  lstm (LSTM)                 (None, 10, 64)               18688     ['input_1[0][0]']
#
#  dense (Dense)               (None, 10, 8)                520       ['lstm[0][0]']
#
#  add (Add)                   (None, 10, 8)                0         ['dense[0][0]',
#                                                                      'input_1[0][0]']
#
#  lstm_1 (LSTM)               (None, 10, 64)               18688     ['add[0][0]']
#
#  dense_1 (Dense)             (None, 10, 8)                520       ['lstm_1[0][0]']
#
#  dense_2 (Dense)             (None, 10, 2)                18        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 38434 (150.13 KB)
# Trainable params: 38434 (150.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=False, show_layer_activations=True)

# %%
# ICLSTM model with relu with t_final = 0.001
# MSE loss 2.4660e-06
# model.save('/content/drive/MyDrive/MPC/model29.h5')
# model = tf.keras.models.load_model('/content/drive/MyDrive/MPC/model29.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
# Out:
# The FLOPs is:96324

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('ICLSTM Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
"""
    equation for the stability ellipse is 1060x^2 + 44xy + 0.52y^2 - 372 = 0
"""
# prepare x and y coordinates for plotting the stability region
y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass


plt.figure(figsize=(10,10))

# # plot the first 10 samples and their trajectories
y_predict = model.predict(X_test)
print(y_predict.shape)

y_predict = y_predict.reshape(-1,2)
y_predict = scaler_y.inverse_transform(y_predict)
y_predict = y_predict.reshape(-1,num_step,2)

X_plot = X_test.reshape(-1,num_dims)
X_plot = scaler_X.inverse_transform(X_plot)
X_plot = X_plot.reshape(-1,num_step,num_dims)

for i in range(10):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':')

# plot stability region
plt.plot(x_lower, y_plot, color='steelblue', label='stability region')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
plt.show()
# Out:
# <ipython-input-23-9998cc70c050>:12: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
# 116/116 [==============================] - 1s 6ms/step
# (3706, 10, 2)

# %%
print(y_predict[8, :, 0])
print(y_test[8, :, 0])
# Out:
# [70.87541  69.97842  69.405075 68.760895 68.19809  67.502174 66.80454
#  66.13652  65.49431  64.88072 ]
# [70.72561539 70.07921788 69.43025205 68.77887103 68.12522131 67.46944305
#  66.81167038 66.15203175 65.49065012 64.82764332]
