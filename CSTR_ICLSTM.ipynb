# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, Conv1D, MaxPooling1D, Flatten
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations
import pickle

# %%
# specifying constant parameters

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
Q_s = 0.0
T_s = 401.8727
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314
C_A0s = 4
C_As = 1.9537
t_final = 0.005
t_step = 1e-4
P = np.array([[1060, 22], [22, 0.52]])

num_step = 10

# %%
# generating inputs and initial states for CSTR, all expressed in deviation form

u1_list = np.linspace(-3.5, 3.5, 4, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 4, endpoint=True)
T_initial = np.linspace(300, 600, 100, endpoint=True) - T_s
CA_initial = np.linspace(0, 6, 100, endpoint=True) - C_As

# %%
# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 372:
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
# Out:
# number of initial conditions: 772
# shape of x_deviation is (772, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """

    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time

    C_A = C_A_initial + C_As
    T = T_initial + T_s

    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)

        T += dTdt * t_step
        C_A += dCAdt * t_step

        if i % 5 == 0:
          C_A_list.append(C_A - C_As)  # in deviation form
          T_list.append(T - T_s)  # in deviation form

    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()
CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()

for u1 in u1_list:
    C_A0 = u1 + C_A0s

    for u2 in u2_list:
        Q = u2 + Q_s

        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)

            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
CA0_input = np.array(CA0_input)
print(CA0_input.shape)
CA_output = np.array(CA_output)
print(CA_output.shape)
# Out:
# (12352,)
# (12352, 10)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

CA0_input_neg = -np.array(CA0_input)
CA0_input_neg = CA0_input_neg.reshape(-1,1,1)

Q_input_neg = -np.array(Q_input)
Q_input_neg = Q_input_neg.reshape(-1,1,1)

CA_input_neg = -np.array(CA_input)
CA_input_neg = CA_input_neg.reshape(-1,1,1)

T_input_neg = -np.array(T_input)
T_input_neg = T_input_neg.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input, T_input_neg, CA_input_neg, Q_input_neg, CA0_input_neg), axis=2)

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""

RNN_input = RNN_input.repeat(num_step, axis=1)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (12352, 10, 8)

# %%
# checking the input is duplicated 100 times for each time step
print(RNN_input[0, 0])
print(RNN_input[0, 1])
# Out:
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, num_step, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, num_step, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (12352, 10, 2)

# %%
# checking output
print(RNN_output[0, :5])
# Out:
# [[-74.82498608   1.43869052]
#  [-75.94937347   1.43097798]
#  [-77.07255531   1.4233169 ]
#  [-78.19443649   1.41570516]
#  [-79.31492759   1.4081408 ]]

# %%
num_dims = 8

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.StandardScaler().fit(X_train.reshape(-1, num_dims))
scaler_y = preprocessing.StandardScaler().fit(y_train.reshape(-1, 2))


X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)

# %%
print("mean of input T, CA, Q, CA0 = ", scaler_X.mean_)
print("std of input T, CA, Q, CA0 = ", scaler_X.scale_)
print("mean of output T, CA = ", scaler_y.mean_)
print("std of output T, CA = ", scaler_y.scale_)
# Out:
# mean of input T, CA, Q, CA0 =  [-6.16908217e-01  1.67119614e-02  1.92767368e+02  1.16045956e-02
#   6.16908217e-01 -1.67119614e-02 -1.92767368e+02 -1.16045956e-02]
# std of input T, CA, Q, CA0 =  [3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00
#  3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00]
# mean of output T, CA =  [-0.75373917  0.01958435]
# std of output T, CA =  [38.78474393  0.84533936]

# %%
from sklearn.preprocessing import normalize
def my_activation(x):
  return normalize(x, norm="l2")

# set the seed for reproducibility
tf.random.set_seed(42)

# input convex LSTM
input = Input(shape=(X_train.shape[1],X_train.shape[2]))
x_skip = input
x = LSTM(64, activation='relu', recurrent_activation=None, recurrent_regularizer='l2', return_sequences=True, kernel_constraint=tf.keras.constraints.NonNeg(), recurrent_constraint=tf.keras.constraints.NonNeg())(input)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Add()([x, x_skip])
x = LSTM(64, activation='relu', recurrent_activation=None, recurrent_regularizer='l2', return_sequences=True, kernel_constraint=tf.keras.constraints.NonNeg(), recurrent_constraint=tf.keras.constraints.NonNeg())(x)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Add()([x, x_skip])
x = Dense(2, activation='linear', kernel_constraint=tf.keras.constraints.NonNeg())(x)
model = Model(input, x)

model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
history = model.fit(X_train, y_train, epochs=500, batch_size=64, validation_split=0.25, verbose=2)
model.summary()
# Out:
# Epoch 1/500
# 102/102 - 8s - loss: 0.9329 - mean_squared_error: 0.6923 - val_loss: 0.4791 - val_mean_squared_error: 0.4234 - 8s/epoch - 80ms/step
# Epoch 2/500
# 102/102 - 2s - loss: 0.2969 - mean_squared_error: 0.2705 - val_loss: 0.1709 - val_mean_squared_error: 0.1587 - 2s/epoch - 16ms/step
# Epoch 3/500
# 102/102 - 2s - loss: 0.1152 - mean_squared_error: 0.1064 - val_loss: 0.0757 - val_mean_squared_error: 0.0688 - 2s/epoch - 16ms/step
# Epoch 4/500
# 102/102 - 2s - loss: 0.0547 - mean_squared_error: 0.0489 - val_loss: 0.0400 - val_mean_squared_error: 0.0350 - 2s/epoch - 15ms/step
# Epoch 5/500
# 102/102 - 2s - loss: 0.0305 - mean_squared_error: 0.0262 - val_loss: 0.0241 - val_mean_squared_error: 0.0204 - 2s/epoch - 18ms/step
# Epoch 6/500
# 102/102 - 2s - loss: 0.0193 - mean_squared_error: 0.0159 - val_loss: 0.0160 - val_mean_squared_error: 0.0130 - 2s/epoch - 22ms/step
# Epoch 7/500
# 102/102 - 2s - loss: 0.0131 - mean_squared_error: 0.0104 - val_loss: 0.0110 - val_mean_squared_error: 0.0086 - 2s/epoch - 15ms/step
# Epoch 8/500
# 102/102 - 1s - loss: 0.0091 - mean_squared_error: 0.0069 - val_loss: 0.0079 - val_mean_squared_error: 0.0058 - 1s/epoch - 15ms/step
# Epoch 9/500
# 102/102 - 2s - loss: 0.0067 - mean_squared_error: 0.0048 - val_loss: 0.0060 - val_mean_squared_error: 0.0043 - 2s/epoch - 16ms/step
# Epoch 10/500
# 102/102 - 2s - loss: 0.0053 - mean_squared_error: 0.0037 - val_loss: 0.0048 - val_mean_squared_error: 0.0033 - 2s/epoch - 15ms/step
# Epoch 11/500
# 102/102 - 2s - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0041 - val_mean_squared_error: 0.0027 - 2s/epoch - 15ms/step
# Epoch 12/500
# 102/102 - 1s - loss: 0.0037 - mean_squared_error: 0.0024 - val_loss: 0.0035 - val_mean_squared_error: 0.0023 - 1s/epoch - 14ms/step
# Epoch 13/500
# 102/102 - 2s - loss: 0.0031 - mean_squared_error: 0.0020 - val_loss: 0.0030 - val_mean_squared_error: 0.0019 - 2s/epoch - 18ms/step
# Epoch 14/500
# 102/102 - 2s - loss: 0.0027 - mean_squared_error: 0.0017 - val_loss: 0.0026 - val_mean_squared_error: 0.0017 - 2s/epoch - 22ms/step
# Epoch 15/500
# 102/102 - 2s - loss: 0.0025 - mean_squared_error: 0.0016 - val_loss: 0.0024 - val_mean_squared_error: 0.0015 - 2s/epoch - 17ms/step
# Epoch 16/500
# 102/102 - 2s - loss: 0.0021 - mean_squared_error: 0.0014 - val_loss: 0.0021 - val_mean_squared_error: 0.0013 - 2s/epoch - 15ms/step
# Epoch 17/500
# 102/102 - 2s - loss: 0.0019 - mean_squared_error: 0.0012 - val_loss: 0.0018 - val_mean_squared_error: 0.0012 - 2s/epoch - 15ms/step
# Epoch 18/500
# 102/102 - 2s - loss: 0.0017 - mean_squared_error: 0.0011 - val_loss: 0.0016 - val_mean_squared_error: 0.0010 - 2s/epoch - 16ms/step
# Epoch 19/500
# 102/102 - 2s - loss: 0.0015 - mean_squared_error: 9.0271e-04 - val_loss: 0.0014 - val_mean_squared_error: 8.9421e-04 - 2s/epoch - 15ms/step
# Epoch 20/500
# 102/102 - 2s - loss: 0.0013 - mean_squared_error: 8.0657e-04 - val_loss: 0.0013 - val_mean_squared_error: 8.0046e-04 - 2s/epoch - 16ms/step
# Epoch 21/500
# 102/102 - 2s - loss: 0.0012 - mean_squared_error: 7.4369e-04 - val_loss: 0.0012 - val_mean_squared_error: 7.2647e-04 - 2s/epoch - 23ms/step
# Epoch 22/500
# 102/102 - 2s - loss: 0.0011 - mean_squared_error: 6.6148e-04 - val_loss: 0.0011 - val_mean_squared_error: 7.2393e-04 - 2s/epoch - 19ms/step
# Epoch 23/500
# 102/102 - 2s - loss: 9.8097e-04 - mean_squared_error: 5.9679e-04 - val_loss: 9.1112e-04 - val_mean_squared_error: 5.4563e-04 - 2s/epoch - 16ms/step
# Epoch 24/500
# 102/102 - 3s - loss: 8.6860e-04 - mean_squared_error: 5.1988e-04 - val_loss: 8.3883e-04 - val_mean_squared_error: 5.0700e-04 - 3s/epoch - 31ms/step
# Epoch 25/500
# 102/102 - 2s - loss: 7.6561e-04 - mean_squared_error: 4.4785e-04 - val_loss: 7.5170e-04 - val_mean_squared_error: 4.4913e-04 - 2s/epoch - 15ms/step
# Epoch 26/500
# 102/102 - 2s - loss: 7.1508e-04 - mean_squared_error: 4.2463e-04 - val_loss: 6.8880e-04 - val_mean_squared_error: 4.1046e-04 - 2s/epoch - 17ms/step
# Epoch 27/500
# 102/102 - 2s - loss: 6.5733e-04 - mean_squared_error: 3.9057e-04 - val_loss: 6.4560e-04 - val_mean_squared_error: 3.9078e-04 - 2s/epoch - 18ms/step
# Epoch 28/500
# 102/102 - 2s - loss: 6.3957e-04 - mean_squared_error: 3.9224e-04 - val_loss: 6.2768e-04 - val_mean_squared_error: 3.9116e-04 - 2s/epoch - 24ms/step
# Epoch 29/500
# 102/102 - 2s - loss: 5.4894e-04 - mean_squared_error: 3.2230e-04 - val_loss: 5.2226e-04 - val_mean_squared_error: 3.0628e-04 - 2s/epoch - 20ms/step
# Epoch 30/500
# 102/102 - 2s - loss: 5.2338e-04 - mean_squared_error: 3.1515e-04 - val_loss: 4.9597e-04 - val_mean_squared_error: 2.9543e-04 - 2s/epoch - 23ms/step
# Epoch 31/500
# 102/102 - 2s - loss: 4.6866e-04 - mean_squared_error: 2.7655e-04 - val_loss: 4.6604e-04 - val_mean_squared_error: 2.8163e-04 - 2s/epoch - 17ms/step
# Epoch 32/500
# 102/102 - 2s - loss: 4.3767e-04 - mean_squared_error: 2.6113e-04 - val_loss: 5.5759e-04 - val_mean_squared_error: 3.8763e-04 - 2s/epoch - 17ms/step
# Epoch 33/500
# 102/102 - 2s - loss: 4.0561e-04 - mean_squared_error: 2.4223e-04 - val_loss: 4.0922e-04 - val_mean_squared_error: 2.5243e-04 - 2s/epoch - 17ms/step
# Epoch 34/500
# 102/102 - 2s - loss: 3.8589e-04 - mean_squared_error: 2.3538e-04 - val_loss: 3.5846e-04 - val_mean_squared_error: 2.1276e-04 - 2s/epoch - 23ms/step
# Epoch 35/500
# 102/102 - 2s - loss: 3.5179e-04 - mean_squared_error: 2.1234e-04 - val_loss: 3.6706e-04 - val_mean_squared_error: 2.3408e-04 - 2s/epoch - 22ms/step
# Epoch 36/500
# 102/102 - 2s - loss: 3.2283e-04 - mean_squared_error: 1.9443e-04 - val_loss: 3.3397e-04 - val_mean_squared_error: 2.1150e-04 - 2s/epoch - 18ms/step
# Epoch 37/500
# 102/102 - 2s - loss: 3.1050e-04 - mean_squared_error: 1.9289e-04 - val_loss: 3.0610e-04 - val_mean_squared_error: 1.9284e-04 - 2s/epoch - 18ms/step
# Epoch 38/500
# 102/102 - 2s - loss: 3.0523e-04 - mean_squared_error: 1.9539e-04 - val_loss: 2.6305e-04 - val_mean_squared_error: 1.5832e-04 - 2s/epoch - 17ms/step
# Epoch 39/500
# 102/102 - 2s - loss: 2.6040e-04 - mean_squared_error: 1.6014e-04 - val_loss: 2.4028e-04 - val_mean_squared_error: 1.4476e-04 - 2s/epoch - 17ms/step
# Epoch 40/500
# 102/102 - 2s - loss: 2.5661e-04 - mean_squared_error: 1.6417e-04 - val_loss: 2.4800e-04 - val_mean_squared_error: 1.5998e-04 - 2s/epoch - 18ms/step
# Epoch 41/500
# 102/102 - 3s - loss: 2.6662e-04 - mean_squared_error: 1.8108e-04 - val_loss: 2.6099e-04 - val_mean_squared_error: 1.7783e-04 - 3s/epoch - 31ms/step
# Epoch 42/500
# 102/102 - 2s - loss: 2.2620e-04 - mean_squared_error: 1.4716e-04 - val_loss: 2.0134e-04 - val_mean_squared_error: 1.2600e-04 - 2s/epoch - 22ms/step
# Epoch 43/500
# 102/102 - 2s - loss: 2.2487e-04 - mean_squared_error: 1.5295e-04 - val_loss: 2.9595e-04 - val_mean_squared_error: 2.2326e-04 - 2s/epoch - 18ms/step
# Epoch 44/500
# 102/102 - 2s - loss: 2.1424e-04 - mean_squared_error: 1.4679e-04 - val_loss: 1.7957e-04 - val_mean_squared_error: 1.1660e-04 - 2s/epoch - 18ms/step
# Epoch 45/500
# 102/102 - 2s - loss: 1.7070e-04 - mean_squared_error: 1.1096e-04 - val_loss: 1.6271e-04 - val_mean_squared_error: 1.0625e-04 - 2s/epoch - 16ms/step
# Epoch 46/500
# 102/102 - 2s - loss: 1.5356e-04 - mean_squared_error: 9.9880e-05 - val_loss: 1.5664e-04 - val_mean_squared_error: 1.0572e-04 - 2s/epoch - 16ms/step
# Epoch 47/500
# 102/102 - 2s - loss: 1.6990e-04 - mean_squared_error: 1.2071e-04 - val_loss: 1.5606e-04 - val_mean_squared_error: 1.0934e-04 - 2s/epoch - 16ms/step
# Epoch 48/500
# 102/102 - 2s - loss: 1.4512e-04 - mean_squared_error: 1.0086e-04 - val_loss: 1.3977e-04 - val_mean_squared_error: 9.7952e-05 - 2s/epoch - 23ms/step
# Epoch 49/500
# 102/102 - 2s - loss: 1.3143e-04 - mean_squared_error: 9.1815e-05 - val_loss: 1.4243e-04 - val_mean_squared_error: 1.0508e-04 - 2s/epoch - 20ms/step
# Epoch 50/500
# 102/102 - 1s - loss: 1.3027e-04 - mean_squared_error: 9.4690e-05 - val_loss: 1.4233e-04 - val_mean_squared_error: 1.0833e-04 - 1s/epoch - 15ms/step
# Epoch 51/500
# 102/102 - 1s - loss: 1.4319e-04 - mean_squared_error: 1.1053e-04 - val_loss: 1.0939e-04 - val_mean_squared_error: 7.9286e-05 - 1s/epoch - 15ms/step
# Epoch 52/500
# 102/102 - 1s - loss: 1.2255e-04 - mean_squared_error: 9.3865e-05 - val_loss: 1.6515e-04 - val_mean_squared_error: 1.3749e-04 - 1s/epoch - 15ms/step
# Epoch 53/500
# 102/102 - 2s - loss: 1.1653e-04 - mean_squared_error: 9.0642e-05 - val_loss: 1.0305e-04 - val_mean_squared_error: 7.9266e-05 - 2s/epoch - 15ms/step
# Epoch 54/500
# 102/102 - 1s - loss: 1.0278e-04 - mean_squared_error: 8.0199e-05 - val_loss: 1.1312e-04 - val_mean_squared_error: 9.1980e-05 - 1s/epoch - 15ms/step
# Epoch 55/500
# 102/102 - 1s - loss: 8.9858e-05 - mean_squared_error: 7.0092e-05 - val_loss: 8.9136e-05 - val_mean_squared_error: 7.0897e-05 - 1s/epoch - 15ms/step
# Epoch 56/500
# 102/102 - 2s - loss: 8.7149e-05 - mean_squared_error: 6.9903e-05 - val_loss: 1.0324e-04 - val_mean_squared_error: 8.7340e-05 - 2s/epoch - 21ms/step
# Epoch 57/500
# 102/102 - 2s - loss: 8.5908e-05 - mean_squared_error: 7.0846e-05 - val_loss: 9.0100e-05 - val_mean_squared_error: 7.6036e-05 - 2s/epoch - 19ms/step
# Epoch 58/500
# 102/102 - 1s - loss: 7.9225e-05 - mean_squared_error: 6.6226e-05 - val_loss: 9.0082e-05 - val_mean_squared_error: 7.7894e-05 - 1s/epoch - 15ms/step
# Epoch 59/500
# 102/102 - 2s - loss: 9.0071e-05 - mean_squared_error: 7.8314e-05 - val_loss: 8.2993e-05 - val_mean_squared_error: 7.2202e-05 - 2s/epoch - 16ms/step
# Epoch 60/500
# 102/102 - 1s - loss: 6.7894e-05 - mean_squared_error: 5.8196e-05 - val_loss: 8.1273e-05 - val_mean_squared_error: 7.2293e-05 - 1s/epoch - 14ms/step
# Epoch 61/500
# 102/102 - 2s - loss: 7.6705e-05 - mean_squared_error: 6.8225e-05 - val_loss: 6.4685e-05 - val_mean_squared_error: 5.6918e-05 - 2s/epoch - 16ms/step
# Epoch 62/500
# 102/102 - 1s - loss: 7.3245e-05 - mean_squared_error: 6.5984e-05 - val_loss: 6.0206e-05 - val_mean_squared_error: 5.3702e-05 - 1s/epoch - 15ms/step
# Epoch 63/500
# 102/102 - 1s - loss: 5.6098e-05 - mean_squared_error: 5.0172e-05 - val_loss: 6.0775e-05 - val_mean_squared_error: 5.5300e-05 - 1s/epoch - 14ms/step
# Epoch 64/500
# 102/102 - 2s - loss: 5.4531e-05 - mean_squared_error: 4.9603e-05 - val_loss: 5.9609e-05 - val_mean_squared_error: 5.5146e-05 - 2s/epoch - 21ms/step
# Epoch 65/500
# 102/102 - 2s - loss: 6.1287e-05 - mean_squared_error: 5.7025e-05 - val_loss: 6.3097e-05 - val_mean_squared_error: 5.9170e-05 - 2s/epoch - 18ms/step
# Epoch 66/500
# 102/102 - 1s - loss: 5.3348e-05 - mean_squared_error: 4.9807e-05 - val_loss: 1.1861e-04 - val_mean_squared_error: 1.1495e-04 - 1s/epoch - 15ms/step
# Epoch 67/500
# 102/102 - 2s - loss: 5.8494e-05 - mean_squared_error: 5.5329e-05 - val_loss: 4.7730e-05 - val_mean_squared_error: 4.5099e-05 - 2s/epoch - 15ms/step
# Epoch 68/500
# 102/102 - 1s - loss: 4.8238e-05 - mean_squared_error: 4.5732e-05 - val_loss: 5.7679e-05 - val_mean_squared_error: 5.5219e-05 - 1s/epoch - 14ms/step
# Epoch 69/500
# 102/102 - 1s - loss: 4.8396e-05 - mean_squared_error: 4.6268e-05 - val_loss: 4.5320e-05 - val_mean_squared_error: 4.3537e-05 - 1s/epoch - 14ms/step
# Epoch 70/500
# 102/102 - 1s - loss: 4.2062e-05 - mean_squared_error: 4.0366e-05 - val_loss: 4.3189e-05 - val_mean_squared_error: 4.1568e-05 - 1s/epoch - 14ms/step
# Epoch 71/500
# 102/102 - 1s - loss: 3.8335e-05 - mean_squared_error: 3.6960e-05 - val_loss: 4.1152e-05 - val_mean_squared_error: 3.9937e-05 - 1s/epoch - 15ms/step
# Epoch 72/500
# 102/102 - 2s - loss: 3.4943e-05 - mean_squared_error: 3.3758e-05 - val_loss: 5.3672e-05 - val_mean_squared_error: 5.2591e-05 - 2s/epoch - 20ms/step
# Epoch 73/500
# 102/102 - 2s - loss: 4.8772e-05 - mean_squared_error: 4.7515e-05 - val_loss: 6.5106e-05 - val_mean_squared_error: 6.3831e-05 - 2s/epoch - 21ms/step
# Epoch 74/500
# 102/102 - 1s - loss: 4.0243e-05 - mean_squared_error: 3.9308e-05 - val_loss: 3.8497e-05 - val_mean_squared_error: 3.7800e-05 - 1s/epoch - 14ms/step
# Epoch 75/500
# 102/102 - 2s - loss: 3.1703e-05 - mean_squared_error: 3.1040e-05 - val_loss: 2.7240e-05 - val_mean_squared_error: 2.6651e-05 - 2s/epoch - 17ms/step
# Epoch 76/500
# 102/102 - 2s - loss: 3.7956e-05 - mean_squared_error: 3.7278e-05 - val_loss: 3.7059e-05 - val_mean_squared_error: 3.6322e-05 - 2s/epoch - 22ms/step
# Epoch 77/500
# 102/102 - 2s - loss: 3.1562e-05 - mean_squared_error: 3.1042e-05 - val_loss: 3.0605e-05 - val_mean_squared_error: 3.0174e-05 - 2s/epoch - 16ms/step
# Epoch 78/500
# 102/102 - 1s - loss: 3.2217e-05 - mean_squared_error: 3.1733e-05 - val_loss: 2.9906e-05 - val_mean_squared_error: 2.9547e-05 - 1s/epoch - 14ms/step
# Epoch 79/500
# 102/102 - 2s - loss: 6.5925e-05 - mean_squared_error: 6.4888e-05 - val_loss: 3.7153e-05 - val_mean_squared_error: 3.6516e-05 - 2s/epoch - 19ms/step
# Epoch 80/500
# 102/102 - 2s - loss: 2.3230e-05 - mean_squared_error: 2.2923e-05 - val_loss: 2.2825e-05 - val_mean_squared_error: 2.2545e-05 - 2s/epoch - 21ms/step
# Epoch 81/500
# 102/102 - 1s - loss: 2.2820e-05 - mean_squared_error: 2.2528e-05 - val_loss: 5.2492e-05 - val_mean_squared_error: 5.2012e-05 - 1s/epoch - 14ms/step
# Epoch 82/500
# 102/102 - 1s - loss: 2.5067e-05 - mean_squared_error: 2.4788e-05 - val_loss: 2.6694e-05 - val_mean_squared_error: 2.6383e-05 - 1s/epoch - 15ms/step
# Epoch 83/500
# 102/102 - 2s - loss: 2.2882e-05 - mean_squared_error: 2.2662e-05 - val_loss: 2.4589e-05 - val_mean_squared_error: 2.4370e-05 - 2s/epoch - 23ms/step
# Epoch 84/500
# 102/102 - 2s - loss: 2.1581e-05 - mean_squared_error: 2.1391e-05 - val_loss: 2.2576e-05 - val_mean_squared_error: 2.2326e-05 - 2s/epoch - 22ms/step
# Epoch 85/500
# 102/102 - 1s - loss: 2.4606e-05 - mean_squared_error: 2.4369e-05 - val_loss: 4.4327e-05 - val_mean_squared_error: 4.3809e-05 - 1s/epoch - 14ms/step
# Epoch 86/500
# 102/102 - 2s - loss: 3.6366e-05 - mean_squared_error: 3.5924e-05 - val_loss: 2.4310e-05 - val_mean_squared_error: 2.3928e-05 - 2s/epoch - 17ms/step
# Epoch 87/500
# 102/102 - 2s - loss: 2.1583e-05 - mean_squared_error: 2.1397e-05 - val_loss: 1.8800e-05 - val_mean_squared_error: 1.8597e-05 - 2s/epoch - 22ms/step
# Epoch 88/500
# 102/102 - 1s - loss: 1.8535e-05 - mean_squared_error: 1.8382e-05 - val_loss: 2.5328e-05 - val_mean_squared_error: 2.5157e-05 - 1s/epoch - 15ms/step
# Epoch 89/500
# 102/102 - 1s - loss: 2.3758e-05 - mean_squared_error: 2.3506e-05 - val_loss: 1.7125e-05 - val_mean_squared_error: 1.6998e-05 - 1s/epoch - 14ms/step
# Epoch 90/500
# 102/102 - 1s - loss: 1.7499e-05 - mean_squared_error: 1.7374e-05 - val_loss: 2.0061e-05 - val_mean_squared_error: 1.9926e-05 - 1s/epoch - 15ms/step
# Epoch 91/500
# 102/102 - 1s - loss: 2.2128e-05 - mean_squared_error: 2.1908e-05 - val_loss: 2.4744e-05 - val_mean_squared_error: 2.4443e-05 - 1s/epoch - 14ms/step
# Epoch 92/500
# 102/102 - 2s - loss: 3.8478e-05 - mean_squared_error: 3.7877e-05 - val_loss: 7.1769e-05 - val_mean_squared_error: 7.0816e-05 - 2s/epoch - 16ms/step
# Epoch 93/500
# 102/102 - 2s - loss: 4.0995e-05 - mean_squared_error: 4.0342e-05 - val_loss: 1.5156e-05 - val_mean_squared_error: 1.5035e-05 - 2s/epoch - 16ms/step
# Epoch 94/500
# 102/102 - 2s - loss: 1.4388e-05 - mean_squared_error: 1.4298e-05 - val_loss: 1.4654e-05 - val_mean_squared_error: 1.4522e-05 - 2s/epoch - 19ms/step
# Epoch 95/500
# 102/102 - 2s - loss: 1.5346e-05 - mean_squared_error: 1.5230e-05 - val_loss: 1.8469e-05 - val_mean_squared_error: 1.8356e-05 - 2s/epoch - 22ms/step
# Epoch 96/500
# 102/102 - 1s - loss: 1.6698e-05 - mean_squared_error: 1.6567e-05 - val_loss: 1.6219e-05 - val_mean_squared_error: 1.6120e-05 - 1s/epoch - 14ms/step
# Epoch 97/500
# 102/102 - 1s - loss: 2.3389e-05 - mean_squared_error: 2.3150e-05 - val_loss: 3.6799e-05 - val_mean_squared_error: 3.6106e-05 - 1s/epoch - 15ms/step
# Epoch 98/500
# 102/102 - 1s - loss: 2.1274e-05 - mean_squared_error: 2.1022e-05 - val_loss: 1.2722e-05 - val_mean_squared_error: 1.2648e-05 - 1s/epoch - 14ms/step
# Epoch 99/500
# 102/102 - 2s - loss: 1.8566e-05 - mean_squared_error: 1.8375e-05 - val_loss: 2.6513e-05 - val_mean_squared_error: 2.6218e-05 - 2s/epoch - 16ms/step
# Epoch 100/500
# 102/102 - 2s - loss: 2.2044e-05 - mean_squared_error: 2.1802e-05 - val_loss: 2.5344e-05 - val_mean_squared_error: 2.5160e-05 - 2s/epoch - 15ms/step
# Epoch 101/500
# 102/102 - 1s - loss: 2.3974e-05 - mean_squared_error: 2.3737e-05 - val_loss: 8.7103e-05 - val_mean_squared_error: 8.6312e-05 - 1s/epoch - 15ms/step
# Epoch 102/500
# 102/102 - 2s - loss: 1.9072e-05 - mean_squared_error: 1.8872e-05 - val_loss: 1.3436e-05 - val_mean_squared_error: 1.3302e-05 - 2s/epoch - 20ms/step
# Epoch 103/500
# 102/102 - 2s - loss: 1.2721e-05 - mean_squared_error: 1.2619e-05 - val_loss: 1.1643e-05 - val_mean_squared_error: 1.1557e-05 - 2s/epoch - 20ms/step
# Epoch 104/500
# 102/102 - 1s - loss: 1.4055e-05 - mean_squared_error: 1.3947e-05 - val_loss: 1.3555e-05 - val_mean_squared_error: 1.3401e-05 - 1s/epoch - 14ms/step
# Epoch 105/500
# 102/102 - 1s - loss: 2.8462e-05 - mean_squared_error: 2.8167e-05 - val_loss: 2.2478e-04 - val_mean_squared_error: 2.2279e-04 - 1s/epoch - 14ms/step
# Epoch 106/500
# 102/102 - 1s - loss: 4.9128e-05 - mean_squared_error: 4.8369e-05 - val_loss: 1.1939e-05 - val_mean_squared_error: 1.1856e-05 - 1s/epoch - 14ms/step
# Epoch 107/500
# 102/102 - 2s - loss: 1.0615e-05 - mean_squared_error: 1.0548e-05 - val_loss: 1.0809e-05 - val_mean_squared_error: 1.0745e-05 - 2s/epoch - 15ms/step
# Epoch 108/500
# 102/102 - 1s - loss: 1.2281e-05 - mean_squared_error: 1.2186e-05 - val_loss: 1.0494e-05 - val_mean_squared_error: 1.0404e-05 - 1s/epoch - 14ms/step
# Epoch 109/500
# 102/102 - 2s - loss: 1.0377e-05 - mean_squared_error: 1.0316e-05 - val_loss: 8.3705e-06 - val_mean_squared_error: 8.3358e-06 - 2s/epoch - 15ms/step
# Epoch 110/500
# 102/102 - 2s - loss: 1.0092e-05 - mean_squared_error: 1.0028e-05 - val_loss: 1.0710e-05 - val_mean_squared_error: 1.0584e-05 - 2s/epoch - 19ms/step
# Epoch 111/500
# 102/102 - 2s - loss: 9.6289e-06 - mean_squared_error: 9.5643e-06 - val_loss: 9.7467e-06 - val_mean_squared_error: 9.6594e-06 - 2s/epoch - 21ms/step
# Epoch 112/500
# 102/102 - 1s - loss: 1.0673e-05 - mean_squared_error: 1.0594e-05 - val_loss: 1.1791e-05 - val_mean_squared_error: 1.1707e-05 - 1s/epoch - 14ms/step
# Epoch 113/500
# 102/102 - 2s - loss: 1.7158e-05 - mean_squared_error: 1.6973e-05 - val_loss: 1.2819e-05 - val_mean_squared_error: 1.2705e-05 - 2s/epoch - 16ms/step
# Epoch 114/500
# 102/102 - 1s - loss: 2.0048e-05 - mean_squared_error: 1.9790e-05 - val_loss: 1.2764e-05 - val_mean_squared_error: 1.2669e-05 - 1s/epoch - 15ms/step
# Epoch 115/500
# 102/102 - 2s - loss: 1.1453e-05 - mean_squared_error: 1.1348e-05 - val_loss: 2.0635e-05 - val_mean_squared_error: 2.0420e-05 - 2s/epoch - 15ms/step
# Epoch 116/500
# 102/102 - 1s - loss: 1.4091e-05 - mean_squared_error: 1.3944e-05 - val_loss: 1.4893e-05 - val_mean_squared_error: 1.4738e-05 - 1s/epoch - 14ms/step
# Epoch 132/500
# 102/102 - 1s - loss: 5.8779e-06 - mean_squared_error: 5.8431e-06 - val_loss: 1.1828e-05 - val_mean_squared_error: 1.1775e-05 - 1s/epoch - 14ms/step
# Epoch 133/500
# 102/102 - 1s - loss: 8.5718e-06 - mean_squared_error: 8.4995e-06 - val_loss: 8.1672e-06 - val_mean_squared_error: 8.1142e-06 - 1s/epoch - 14ms/step
# Epoch 134/500
# 102/102 - 2s - loss: 6.2884e-06 - mean_squared_error: 6.2448e-06 - val_loss: 4.4389e-06 - val_mean_squared_error: 4.4185e-06 - 2s/epoch - 17ms/step
# Epoch 135/500
# 102/102 - 2s - loss: 5.6889e-06 - mean_squared_error: 5.6552e-06 - val_loss: 8.0252e-06 - val_mean_squared_error: 7.9747e-06 - 2s/epoch - 22ms/step
# Epoch 136/500
# 102/102 - 1s - loss: 1.0266e-05 - mean_squared_error: 1.0159e-05 - val_loss: 1.4991e-05 - val_mean_squared_error: 1.4848e-05 - 1s/epoch - 14ms/step
# Epoch 137/500
# 102/102 - 2s - loss: 6.7146e-06 - mean_squared_error: 6.6622e-06 - val_loss: 1.2322e-05 - val_mean_squared_error: 1.2245e-05 - 2s/epoch - 15ms/step
# Epoch 138/500
# 102/102 - 2s - loss: 2.7311e-05 - mean_squared_error: 2.7001e-05 - val_loss: 3.9728e-05 - val_mean_squared_error: 3.9039e-05 - 2s/epoch - 15ms/step
# Epoch 139/500
# 102/102 - 1s - loss: 1.5547e-05 - mean_squared_error: 1.5378e-05 - val_loss: 8.1268e-06 - val_mean_squared_error: 8.0567e-06 - 1s/epoch - 14ms/step
# Epoch 140/500
# 102/102 - 1s - loss: 5.7740e-06 - mean_squared_error: 5.7336e-06 - val_loss: 8.3005e-06 - val_mean_squared_error: 8.2059e-06 - 1s/epoch - 14ms/step
# Epoch 141/500
# 102/102 - 2s - loss: 6.4535e-06 - mean_squared_error: 6.4060e-06 - val_loss: 4.5473e-06 - val_mean_squared_error: 4.5294e-06 - 2s/epoch - 16ms/step
# Epoch 142/500
# 102/102 - 2s - loss: 5.0975e-06 - mean_squared_error: 5.0702e-06 - val_loss: 4.1492e-06 - val_mean_squared_error: 4.1301e-06 - 2s/epoch - 17ms/step
# Epoch 143/500
# 102/102 - 2s - loss: 8.3906e-06 - mean_squared_error: 8.3194e-06 - val_loss: 5.1970e-06 - val_mean_squared_error: 5.1343e-06 - 2s/epoch - 22ms/step
# Epoch 144/500
# 102/102 - 2s - loss: 4.3277e-06 - mean_squared_error: 4.3036e-06 - val_loss: 6.6944e-06 - val_mean_squared_error: 6.6481e-06 - 2s/epoch - 15ms/step
# Epoch 145/500
# 102/102 - 1s - loss: 1.0461e-05 - mean_squared_error: 1.0364e-05 - val_loss: 2.3009e-05 - val_mean_squared_error: 2.2772e-05 - 1s/epoch - 15ms/step
# Epoch 146/500
# 102/102 - 1s - loss: 9.2227e-06 - mean_squared_error: 9.1330e-06 - val_loss: 2.7068e-05 - val_mean_squared_error: 2.6618e-05 - 1s/epoch - 15ms/step
# Epoch 147/500
# Epoch 268/500
# 102/102 - 1s - loss: 3.2171e-06 - mean_squared_error: 3.1910e-06 - val_loss: 1.2023e-05 - val_mean_squared_error: 1.1869e-05 - 1s/epoch - 14ms/step
# Epoch 269/500
# 102/102 - 1s - loss: 7.8404e-06 - mean_squared_error: 7.7726e-06 - val_loss: 2.6893e-06 - val_mean_squared_error: 2.6655e-06 - 1s/epoch - 15ms/step
# Epoch 270/500
# 102/102 - 2s - loss: 3.3053e-06 - mean_squared_error: 3.2796e-06 - val_loss: 2.9777e-06 - val_mean_squared_error: 2.9603e-06 - 2s/epoch - 16ms/step
# Epoch 271/500
# 102/102 - 2s - loss: 1.6527e-06 - mean_squared_error: 1.6432e-06 - val_loss: 2.5343e-06 - val_mean_squared_error: 2.4946e-06 - 2s/epoch - 21ms/step
# Epoch 272/500
# 102/102 - 2s - loss: 2.0089e-06 - mean_squared_error: 1.9936e-06 - val_loss: 1.9081e-06 - val_mean_squared_error: 1.8906e-06 - 2s/epoch - 17ms/step
# Epoch 273/500
# 102/102 - 2s - loss: 2.4144e-06 - mean_squared_error: 2.3961e-06 - val_loss: 1.9939e-06 - val_mean_squared_error: 1.9841e-06 - 2s/epoch - 16ms/step
# Epoch 274/500
# 102/102 - 1s - loss: 6.8934e-06 - mean_squared_error: 6.8304e-06 - val_loss: 7.4488e-06 - val_mean_squared_error: 7.3862e-06 - 1s/epoch - 15ms/step
# Epoch 275/500
# 102/102 - 1s - loss: 1.0088e-05 - mean_squared_error: 9.9870e-06 - val_loss: 5.4344e-05 - val_mean_squared_error: 5.3824e-05 - 1s/epoch - 15ms/step
# Epoch 276/500
# 102/102 - 1s - loss: 8.3754e-06 - mean_squared_error: 8.2916e-06 - val_loss: 3.2513e-06 - val_mean_squared_error: 3.2161e-06 - 1s/epoch - 14ms/step
# Epoch 277/500
# 102/102 - 1s - loss: 2.2379e-06 - mean_squared_error: 2.2204e-06 - val_loss: 2.0168e-06 - val_mean_squared_error: 2.0111e-06 - 1s/epoch - 15ms/step
# Epoch 278/500
# 102/102 - 2s - loss: 1.1800e-06 - mean_squared_error: 1.1734e-06 - val_loss: 3.1289e-06 - val_mean_squared_error: 3.1062e-06 - 2s/epoch - 16ms/step
# Epoch 279/500
# 102/102 - 2s - loss: 1.4989e-06 - mean_squared_error: 1.4894e-06 - val_loss: 8.5960e-07 - val_mean_squared_error: 8.5353e-07 - 2s/epoch - 21ms/step
# Epoch 280/500
# 102/102 - 2s - loss: 1.1047e-06 - mean_squared_error: 1.0987e-06 - val_loss: 1.0723e-06 - val_mean_squared_error: 1.0693e-06 - 2s/epoch - 17ms/step
# Epoch 281/500
# 102/102 - 1s - loss: 1.3669e-06 - mean_squared_error: 1.3583e-06 - val_loss: 6.4289e-06 - val_mean_squared_error: 6.3378e-06 - 1s/epoch - 14ms/step
# Epoch 282/500
# 102/102 - 1s - loss: 7.0399e-06 - mean_squared_error: 6.9777e-06 - val_loss: 3.0899e-06 - val_mean_squared_error: 3.0670e-06 - 1s/epoch - 15ms/step
# Epoch 283/500
# 102/102 - 1s - loss: 9.5135e-07 - mean_squared_error: 9.4767e-07 - val_loss: 8.7024e-07 - val_mean_squared_error: 8.6661e-07 - 1s/epoch - 14ms/step
# Epoch 299/500
# ...
# 102/102 - 1s - loss: 1.0529e-05 - mean_squared_error: 1.0440e-05 - val_loss: 5.9326e-05 - val_mean_squared_error: 5.8780e-05 - 1s/epoch - 14ms/step
# Epoch 418/500
# 102/102 - 1s - loss: 1.4541e-05 - mean_squared_error: 1.4434e-05 - val_loss: 1.1853e-06 - val_mean_squared_error: 1.1821e-06 - 1s/epoch - 15ms/step
# Epoch 419/500
# 102/102 - 1s - loss: 7.4844e-07 - mean_squared_error: 7.4561e-07 - val_loss: 5.4589e-07 - val_mean_squared_error: 5.4374e-07 - 1s/epoch - 14ms/step
# Epoch 420/500
# 102/102 - 1s - loss: 5.6352e-07 - mean_squared_error: 5.6148e-07 - val_loss: 7.1710e-07 - val_mean_squared_error: 7.0833e-07 - 1s/epoch - 14ms/step
# Epoch 421/500
# 102/102 - 2s - loss: 5.5023e-07 - mean_squared_error: 5.4792e-07 - val_loss: 5.9161e-07 - val_mean_squared_error: 5.8914e-07 - 2s/epoch - 15ms/step
# Epoch 422/500
# 102/102 - 2s - loss: 5.8492e-07 - mean_squared_error: 5.8237e-07 - val_loss: 7.5504e-07 - val_mean_squared_error: 7.5089e-07 - 2s/epoch - 15ms/step
# Epoch 423/500
# 102/102 - 2s - loss: 1.4066e-06 - mean_squared_error: 1.3968e-06 - val_loss: 1.0258e-06 - val_mean_squared_error: 1.0208e-06 - 2s/epoch - 21ms/step
# Epoch 424/500
# 102/102 - 2s - loss: 5.6923e-07 - mean_squared_error: 5.6656e-07 - val_loss: 7.8312e-07 - val_mean_squared_error: 7.7880e-07 - 2s/epoch - 19ms/step
# Epoch 425/500
# 102/102 - 2s - loss: 1.3590e-06 - mean_squared_error: 1.3473e-06 - val_loss: 1.9948e-06 - val_mean_squared_error: 1.9853e-06 - 2s/epoch - 15ms/step
# Epoch 426/500
# 102/102 - 2s - loss: 1.9420e-06 - mean_squared_error: 1.9262e-06 - val_loss: 1.5538e-06 - val_mean_squared_error: 1.5338e-06 - 2s/epoch - 16ms/step
# Epoch 427/500
# 102/102 - 2s - loss: 1.0601e-06 - mean_squared_error: 1.0519e-06 - val_loss: 5.4340e-06 - val_mean_squared_error: 5.3885e-06 - 2s/epoch - 15ms/step
# Epoch 428/500
# 102/102 - 1s - loss: 1.8034e-06 - mean_squared_error: 1.7892e-06 - val_loss: 3.2297e-06 - val_mean_squared_error: 3.1791e-06 - 1s/epoch - 14ms/step
# Epoch 429/500
# 102/102 - 1s - loss: 1.7770e-06 - mean_squared_error: 1.7635e-06 - val_loss: 4.0381e-06 - val_mean_squared_error: 4.0186e-06 - 1s/epoch - 15ms/step
# Epoch 430/500
# 102/102 - 2s - loss: 5.0494e-06 - mean_squared_error: 5.0046e-06 - val_loss: 3.2798e-06 - val_mean_squared_error: 3.2247e-06 - 2s/epoch - 16ms/step
# Epoch 431/500
# 102/102 - 2s - loss: 1.6440e-06 - mean_squared_error: 1.6313e-06 - val_loss: 1.2868e-05 - val_mean_squared_error: 1.2730e-05 - 2s/epoch - 21ms/step
# Epoch 432/500
# 102/102 - 2s - loss: 5.5355e-06 - mean_squared_error: 5.4947e-06 - val_loss: 3.9814e-06 - val_mean_squared_error: 3.9572e-06 - 2s/epoch - 17ms/step
# Epoch 433/500
# 102/102 - 1s - loss: 2.4376e-06 - mean_squared_error: 2.4182e-06 - val_loss: 1.8199e-06 - val_mean_squared_error: 1.8049e-06 - 1s/epoch - 14ms/step
# Epoch 434/500
# 102/102 - 2s - loss: 8.3460e-06 - mean_squared_error: 8.2842e-06 - val_loss: 1.8380e-05 - val_mean_squared_error: 1.8277e-05 - 2s/epoch - 15ms/step
# Epoch 435/500
# 102/102 - 2s - loss: 5.4581e-06 - mean_squared_error: 5.4161e-06 - val_loss: 1.8400e-06 - val_mean_squared_error: 1.8089e-06 - 2s/epoch - 15ms/step
# Epoch 436/500
# 102/102 - 2s - loss: 7.1789e-07 - mean_squared_error: 7.1443e-07 - val_loss: 5.7629e-07 - val_mean_squared_error: 5.7145e-07 - 2s/epoch - 15ms/step
# Epoch 437/500
# 102/102 - 1s - loss: 7.1837e-07 - mean_squared_error: 7.1464e-07 - val_loss: 5.4561e-07 - val_mean_squared_error: 5.4345e-07 - 1s/epoch - 15ms/step
# Epoch 438/500
# 102/102 - 1s - loss: 7.1330e-07 - mean_squared_error: 7.0912e-07 - val_loss: 1.5984e-06 - val_mean_squared_error: 1.5865e-06 - 1s/epoch - 14ms/step
# Epoch 439/500
# 102/102 - 2s - loss: 2.3441e-06 - mean_squared_error: 2.3258e-06 - val_loss: 2.8754e-06 - val_mean_squared_error: 2.8416e-06 - 2s/epoch - 21ms/step
# Epoch 440/500
# 102/102 - 2s - loss: 1.7984e-06 - mean_squared_error: 1.7843e-06 - val_loss: 4.2624e-06 - val_mean_squared_error: 4.2065e-06 - 2s/epoch - 18ms/step
# Epoch 441/500
# 102/102 - 1s - loss: 6.3567e-06 - mean_squared_error: 6.3021e-06 - val_loss: 1.2372e-06 - val_mean_squared_error: 1.2317e-06 - 1s/epoch - 15ms/step
# Epoch 442/500
# 102/102 - 2s - loss: 2.0080e-06 - mean_squared_error: 1.9945e-06 - val_loss: 3.8156e-06 - val_mean_squared_error: 3.7887e-06 - 2s/epoch - 16ms/step
# Epoch 443/500
# 102/102 - 1s - loss: 3.5208e-06 - mean_squared_error: 3.4941e-06 - val_loss: 2.4172e-06 - val_mean_squared_error: 2.3798e-06 - 1s/epoch - 15ms/step
# Epoch 444/500
# 102/102 - 1s - loss: 3.9362e-06 - mean_squared_error: 3.9056e-06 - val_loss: 7.3444e-07 - val_mean_squared_error: 7.3246e-07 - 1s/epoch - 14ms/step
# Epoch 445/500
# 102/102 - 1s - loss: 6.7714e-07 - mean_squared_error: 6.7345e-07 - val_loss: 1.1136e-06 - val_mean_squared_error: 1.1090e-06 - 1s/epoch - 14ms/step
# Epoch 446/500
# 102/102 - 1s - loss: 8.9628e-07 - mean_squared_error: 8.9126e-07 - val_loss: 6.4905e-07 - val_mean_squared_error: 6.4595e-07 - 1s/epoch - 14ms/step
# Epoch 447/500
# 102/102 - 2s - loss: 1.3396e-06 - mean_squared_error: 1.3301e-06 - val_loss: 1.1600e-06 - val_mean_squared_error: 1.1518e-06 - 2s/epoch - 20ms/step
# Epoch 448/500
# 102/102 - 2s - loss: 2.3143e-06 - mean_squared_error: 2.2942e-06 - val_loss: 7.0169e-06 - val_mean_squared_error: 6.9950e-06 - 2s/epoch - 19ms/step
# Epoch 449/500
# 102/102 - 2s - loss: 1.3356e-05 - mean_squared_error: 1.3258e-05 - val_loss: 2.9501e-06 - val_mean_squared_error: 2.8886e-06 - 2s/epoch - 15ms/step
# Epoch 450/500
# 102/102 - 1s - loss: 1.4631e-06 - mean_squared_error: 1.4526e-06 - val_loss: 4.6215e-07 - val_mean_squared_error: 4.6009e-07 - 1s/epoch - 15ms/step
# Epoch 451/500
# 102/102 - 1s - loss: 5.4014e-07 - mean_squared_error: 5.3754e-07 - val_loss: 8.4287e-07 - val_mean_squared_error: 8.3617e-07 - 1s/epoch - 15ms/step
# Epoch 452/500
# 102/102 - 2s - loss: 6.6117e-07 - mean_squared_error: 6.5760e-07 - val_loss: 6.3653e-07 - val_mean_squared_error: 6.3085e-07 - 2s/epoch - 15ms/step
# Epoch 453/500
# 102/102 - 2s - loss: 7.2375e-07 - mean_squared_error: 7.1969e-07 - val_loss: 7.5588e-07 - val_mean_squared_error: 7.5043e-07 - 2s/epoch - 16ms/step
# Epoch 454/500
# 102/102 - 2s - loss: 5.9983e-07 - mean_squared_error: 5.9679e-07 - val_loss: 8.8640e-07 - val_mean_squared_error: 8.8276e-07 - 2s/epoch - 16ms/step
# Epoch 455/500
# 102/102 - 2s - loss: 8.5761e-07 - mean_squared_error: 8.5245e-07 - val_loss: 2.3636e-06 - val_mean_squared_error: 2.3469e-06 - 2s/epoch - 23ms/step
# Epoch 456/500
# 102/102 - 2s - loss: 1.2747e-05 - mean_squared_error: 1.2647e-05 - val_loss: 1.3149e-05 - val_mean_squared_error: 1.3115e-05 - 2s/epoch - 17ms/step
# Epoch 457/500
# 102/102 - 1s - loss: 3.2609e-06 - mean_squared_error: 3.2385e-06 - val_loss: 7.1651e-07 - val_mean_squared_error: 7.0914e-07 - 1s/epoch - 15ms/step
# Epoch 458/500
# 102/102 - 2s - loss: 5.7607e-07 - mean_squared_error: 5.7327e-07 - val_loss: 5.8173e-07 - val_mean_squared_error: 5.7851e-07 - 2s/epoch - 15ms/step
# Epoch 459/500
# 102/102 - 1s - loss: 5.5947e-07 - mean_squared_error: 5.5695e-07 - val_loss: 8.0024e-07 - val_mean_squared_error: 7.9877e-07 - 1s/epoch - 15ms/step
# Epoch 460/500
# 102/102 - 2s - loss: 6.0199e-07 - mean_squared_error: 5.9860e-07 - val_loss: 8.9186e-07 - val_mean_squared_error: 8.8759e-07 - 2s/epoch - 15ms/step
# Epoch 461/500
# Epoch 492/500
# 102/102 - 1s - loss: 5.3328e-07 - mean_squared_error: 5.3041e-07 - val_loss: 6.6496e-07 - val_mean_squared_error: 6.6249e-07 - 1s/epoch - 14ms/step
# Epoch 493/500
# 102/102 - 1s - loss: 5.3468e-07 - mean_squared_error: 5.3180e-07 - val_loss: 2.7285e-06 - val_mean_squared_error: 2.7127e-06 - 1s/epoch - 14ms/step
# Epoch 494/500
# 102/102 - 1s - loss: 1.1194e-06 - mean_squared_error: 1.1103e-06 - val_loss: 6.3999e-07 - val_mean_squared_error: 6.3808e-07 - 1s/epoch - 14ms/step
# Epoch 495/500
# 102/102 - 2s - loss: 6.4615e-06 - mean_squared_error: 6.4073e-06 - val_loss: 6.7526e-06 - val_mean_squared_error: 6.6957e-06 - 2s/epoch - 20ms/step
# Epoch 496/500
# 102/102 - 2s - loss: 2.2204e-06 - mean_squared_error: 2.2047e-06 - val_loss: 1.2445e-06 - val_mean_squared_error: 1.2337e-06 - 2s/epoch - 20ms/step
# Epoch 497/500
# 102/102 - 2s - loss: 1.1310e-06 - mean_squared_error: 1.1224e-06 - val_loss: 5.5217e-07 - val_mean_squared_error: 5.4677e-07 - 2s/epoch - 16ms/step
# Epoch 498/500
# 102/102 - 1s - loss: 7.7074e-07 - mean_squared_error: 7.6627e-07 - val_loss: 5.6900e-07 - val_mean_squared_error: 5.6418e-07 - 1s/epoch - 14ms/step
# Epoch 499/500
# 102/102 - 1s - loss: 6.6084e-07 - mean_squared_error: 6.5664e-07 - val_loss: 6.6764e-07 - val_mean_squared_error: 6.6558e-07 - 1s/epoch - 14ms/step
# Epoch 500/500
# 102/102 - 1s - loss: 6.8910e-07 - mean_squared_error: 6.8453e-07 - val_loss: 8.8970e-07 - val_mean_squared_error: 8.8387e-07 - 1s/epoch - 14ms/step
# Model: "model_40"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_48 (InputLayer)       [(None, 10, 8)]              0         []
#
#  lstm_136 (LSTM)             (None, 10, 64)               18688     ['input_48[0][0]']
#
#  dense_171 (Dense)           (None, 10, 8)                520       ['lstm_136[0][0]']
#
#  add_71 (Add)                (None, 10, 8)                0         ['dense_171[0][0]',
#                                                                      'input_48[0][0]']
#
#  lstm_137 (LSTM)             (None, 10, 64)               18688     ['add_71[0][0]']
#
#  dense_172 (Dense)           (None, 10, 8)                520       ['lstm_137[0][0]']
#
#  add_72 (Add)                (None, 10, 8)                0         ['dense_172[0][0]',
#                                                                      'input_48[0][0]']
#
#  dense_173 (Dense)           (None, 10, 2)                18        ['add_72[0][0]']
#
# ==================================================================================================
# Total params: 38434 (150.13 KB)
# Trainable params: 38434 (150.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=False, show_layer_activations=True)

# %%
# ICLSTM model with relu with t_final = 0.001
# MSE loss 8.8387e-07
# model.save('/content/drive/MyDrive/MPC/model29.h5')
# model = tf.keras.models.load_model('/content/drive/MyDrive/MPC/model29.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# The FLOPs is:96404

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('ICLSTM Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
"""
    equation for the stability ellipse is 1060x^2 + 44xy + 0.52y^2 - 372 = 0
"""
# prepare x and y coordinates for plotting the stability region
y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass


plt.figure(figsize=(10,10))

# # plot the first 10 samples and their trajectories
y_predict = model.predict(X_test)
print(y_predict.shape)

y_predict = y_predict.reshape(-1,2)
y_predict = scaler_y.inverse_transform(y_predict)
y_predict = y_predict.reshape(-1,num_step,2)

X_plot = X_test.reshape(-1,num_dims)
X_plot = scaler_X.inverse_transform(X_plot)
X_plot = X_plot.reshape(-1,num_step,num_dims)

for i in range(10):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':')

# plot stability region
plt.plot(x_lower, y_plot, color='steelblue', label='stability region')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
plt.show()
# Out:
# <ipython-input-196-9998cc70c050>:12: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
# 116/116 [==============================] - 1s 4ms/step
# (3706, 10, 2)

# %%
print(y_predict[8, :, 0])
print(y_test[8, :, 0])
# Out:
# [70.68932  70.06915  69.411865 68.75126  68.118256 67.47659  66.82555
#  66.165474 65.497284 64.82202 ]
# [70.72561539 70.07921788 69.43025205 68.77887103 68.12522131 67.46944305
#  66.81167038 66.15203175 65.49065012 64.82764332]
