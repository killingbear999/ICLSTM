# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, Conv1D, MaxPooling1D, Flatten
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
import pickle

# %%
# specifying constant parameters

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
Q_s = 0.0
T_s = 401.8727
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314
C_A0s = 4
C_As = 1.9537

t_final = 0.005
t_step = 1e-4
P = np.array([[1060, 22], [22, 0.52]])

num_step = 10

# %%
# generating inputs and initial states for CSTR, all expressed in deviation form

u1_list = np.linspace(-3.5, 3.5, 4, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 4, endpoint=True)
T_initial = np.linspace(300, 600, 100, endpoint=True) - T_s
CA_initial = np.linspace(0, 6, 100, endpoint=True) - C_As

# %%
# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 372:
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
# Out:
# number of initial conditions: 772
# shape of x_deviation is (772, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """

    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time

    C_A = C_A_initial + C_As
    T = T_initial + T_s

    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)

        T += dTdt * t_step
        C_A += dCAdt * t_step

        if i % 5 == 0:
          C_A_list.append(C_A - C_As)  # in deviation form
          T_list.append(T - T_s)  # in deviation form

    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()
CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()

for u1 in u1_list:
    C_A0 = u1 + C_A0s

    for u2 in u2_list:
        Q = u2 + Q_s

        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)

            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
CA0_input = np.array(CA0_input)
print(CA0_input.shape)
CA_output = np.array(CA_output)
print(CA_output.shape)
# Out:
# (12352,)
# (12352, 10)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input, -T_input, -CA_input, -Q_input, -CA0_input), axis=2)

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""

RNN_input = RNN_input.repeat(num_step, axis=1)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (12352, 10, 8)

# %%
# checking the input is duplicated 100 times for each time step
print(RNN_input[0, 0])
print(RNN_input[0, 1])
# Out:
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, num_step, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, num_step, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (12352, 10, 2)

# %%
# checking output
print(RNN_output[0, :5])
# Out:
# [[-74.82498608   1.43869052]
#  [-75.94937347   1.43097798]
#  [-77.07255531   1.4233169 ]
#  [-78.19443649   1.41570516]
#  [-79.31492759   1.4081408 ]]

# %%
num_dims = 8

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.StandardScaler().fit(X_train.reshape(-1, num_dims))
scaler_y = preprocessing.StandardScaler().fit(y_train.reshape(-1, 2))


X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)

# %%
print("mean of input T, CA, Q, CA0 = ", scaler_X.mean_)
print("std of input T, CA, Q, CA0 = ", scaler_X.scale_)
print("mean of output T, CA = ", scaler_y.mean_)
print("std of output T, CA = ", scaler_y.scale_)
# Out:
# mean of input T, CA, Q, CA0 =  [-6.16908217e-01  1.67119614e-02  1.92767368e+02  1.16045956e-02
#   6.16908217e-01 -1.67119614e-02 -1.92767368e+02 -1.16045956e-02]
# std of input T, CA, Q, CA0 =  [3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00
#  3.85278325e+01 8.49360686e-01 3.73882913e+05 2.61161518e+00]
# mean of output T, CA =  [-0.75373917  0.01958435]
# std of output T, CA =  [38.78474393  0.84533936]

# %%
# ICLSTM
class MyICLSTMCell(tf.keras.layers.Layer):

    def __init__(self, units, **kwargs):
        self.units = units
        self.state_size = [self.units, self.units]
        super(MyICLSTMCell, self).__init__(**kwargs)

    def build(self, input_shape):
        self.Wi = self.add_weight(shape=(input_shape[-1], self.units),
                                      initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
                                      name='Wi',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.Ui = self.add_weight(shape=(self.units, self.units),
                                      initializer=initializers.Orthogonal(0.1),
                                      name='Ui',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.DWi = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DWi',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.DUi = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DUi',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.bi = self.add_weight(shape=(self.units,), initializer='zeros', name='bi', trainable=True)

        self.DWf = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DWf',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.DUf = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DUf',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.bf = self.add_weight(shape=(self.units,), initializer='zeros', name='bf', trainable=True)

        self.DWo = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DWo',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.DUo = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DUo',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.bo = self.add_weight(shape=(self.units,), initializer='zeros', name='bo', trainable=True)

        self.DWc = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DWc',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.DUc = self.add_weight(shape=(self.units,),
                                      initializer=initializers.RandomUniform(minval=0, maxval=1),
                                      name='DUc',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.bc = self.add_weight(shape=(self.units,), initializer='zeros', name='bc', trainable=True)

        self.built = True

    def call(self, inputs, states):
        h_tm1 = states[0]  # previous hidden state
        c_tm1 = states[1]  # previous cell state

        # scaling version
        i = tf.nn.relu(self.DWi * K.dot(inputs, self.Wi) + self.DUi * K.dot(h_tm1, self.Ui) + self.bi)
        f = tf.nn.relu(self.DWf * K.dot(inputs, self.Wi) + self.DUf * K.dot(h_tm1, self.Ui) + self.bf)
        o = tf.nn.relu(self.DWo * K.dot(inputs, self.Wi) + self.DUo * K.dot(h_tm1, self.Ui) + self.bo)
        c = tf.nn.relu(self.DWc * K.dot(inputs, self.Wi) + self.DUc * K.dot(h_tm1, self.Ui) + self.bc)

        new_c = f * c_tm1 + i * c
        new_h = o * tf.nn.relu(new_c)

        return new_h, [new_h, new_c]

    def get_config(self):
        config = super(MyICLSTMCell, self).get_config()
        config.update({"units": self.units})
        return config

# set the seed for reproducibility
tf.random.set_seed(42)

# ICLSTM
input = Input(shape=(X_train.shape[1],X_train.shape[2]))
x_skip = input
x = RNN(MyICLSTMCell(units=64),return_sequences=True)(input)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Add()([x, x_skip])
x = RNN(MyICLSTMCell(units=64),return_sequences=True)(x)
x = Dense(X_train.shape[2], activation='relu', kernel_constraint=tf.keras.constraints.NonNeg())(x)
x = Add()([x, x_skip])
x = Dense(2, activation='linear', kernel_constraint=tf.keras.constraints.NonNeg())(x)
model = Model(input, x)

# # simple ICRNN
# nh = 64
# input = Input(shape=(X_train.shape[1],X_train.shape[2]))
# x_skip = input
# x = SimpleRNN(nh, activation='relu',
#          kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
#          recurrent_initializer=initializers.Orthogonal(0.1),
#          return_sequences=True,
#          kernel_constraint=tf.keras.constraints.NonNeg(),
#          recurrent_constraint=tf.keras.constraints.NonNeg()
#          )(input)
# x = Dense(X_train.shape[2], activation='relu',
#           kernel_constraint=tf.keras.constraints.NonNeg()
#           )(x)
# x = Add()([x, x_skip])
# x = SimpleRNN(nh, activation='relu',
#          kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
#          recurrent_initializer=initializers.Orthogonal(0.1),
#          return_sequences=True,
#          kernel_constraint=tf.keras.constraints.NonNeg(),
#          recurrent_constraint=tf.keras.constraints.NonNeg()
#          )(x)
# x = Dense(X_train.shape[2], activation='relu',
#           kernel_constraint=tf.keras.constraints.NonNeg()
#           )(x)
# x = Add()([x, x_skip])
# x = Dense(2, activation='linear',
#           kernel_constraint=tf.keras.constraints.NonNeg()
#           )(x)
# model = Model(input, x)

model.compile(optimizer=Adam(clipnorm=None), loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
history = model.fit(X_train, y_train, epochs=200, batch_size=256, validation_split=0.25, verbose=2)
model.summary()
# Out:
# Epoch 1/200
# 26/26 - 15s - loss: 1.5857 - mean_squared_error: 1.5857 - val_loss: 1.2795 - val_mean_squared_error: 1.2795 - 15s/epoch - 588ms/step
# Epoch 2/200
# 26/26 - 1s - loss: 1.2444 - mean_squared_error: 1.2444 - val_loss: 1.0798 - val_mean_squared_error: 1.0798 - 1s/epoch - 46ms/step
# Epoch 3/200
# 26/26 - 1s - loss: 1.0151 - mean_squared_error: 1.0151 - val_loss: 0.8698 - val_mean_squared_error: 0.8698 - 1s/epoch - 49ms/step
# Epoch 4/200
# 26/26 - 1s - loss: 0.8157 - mean_squared_error: 0.8157 - val_loss: 0.6890 - val_mean_squared_error: 0.6890 - 1s/epoch - 50ms/step
# Epoch 5/200
# 26/26 - 2s - loss: 0.6998 - mean_squared_error: 0.6998 - val_loss: 0.6034 - val_mean_squared_error: 0.6034 - 2s/epoch - 77ms/step
# Epoch 6/200
# 26/26 - 2s - loss: 0.5827 - mean_squared_error: 0.5827 - val_loss: 0.5115 - val_mean_squared_error: 0.5115 - 2s/epoch - 85ms/step
# Epoch 7/200
# 26/26 - 1s - loss: 0.4846 - mean_squared_error: 0.4846 - val_loss: 0.4171 - val_mean_squared_error: 0.4171 - 1s/epoch - 47ms/step
# Epoch 8/200
# 26/26 - 1s - loss: 0.3953 - mean_squared_error: 0.3953 - val_loss: 0.3427 - val_mean_squared_error: 0.3427 - 1s/epoch - 47ms/step
# Epoch 9/200
# 26/26 - 1s - loss: 0.3230 - mean_squared_error: 0.3230 - val_loss: 0.2774 - val_mean_squared_error: 0.2774 - 1s/epoch - 47ms/step
# Epoch 10/200
# 26/26 - 1s - loss: 0.2624 - mean_squared_error: 0.2624 - val_loss: 0.2261 - val_mean_squared_error: 0.2261 - 1s/epoch - 46ms/step
# Epoch 11/200
# 26/26 - 1s - loss: 0.2061 - mean_squared_error: 0.2061 - val_loss: 0.1783 - val_mean_squared_error: 0.1783 - 1s/epoch - 47ms/step
# Epoch 12/200
# 26/26 - 1s - loss: 0.1639 - mean_squared_error: 0.1639 - val_loss: 0.1409 - val_mean_squared_error: 0.1409 - 1s/epoch - 47ms/step
# Epoch 13/200
# 26/26 - 1s - loss: 0.1324 - mean_squared_error: 0.1324 - val_loss: 0.1155 - val_mean_squared_error: 0.1155 - 1s/epoch - 46ms/step
# Epoch 14/200
# 26/26 - 1s - loss: 0.1099 - mean_squared_error: 0.1099 - val_loss: 0.0970 - val_mean_squared_error: 0.0970 - 1s/epoch - 45ms/step
# Epoch 15/200
# 26/26 - 2s - loss: 0.0938 - mean_squared_error: 0.0938 - val_loss: 0.0838 - val_mean_squared_error: 0.0838 - 2s/epoch - 78ms/step
# Epoch 16/200
# 26/26 - 2s - loss: 0.0812 - mean_squared_error: 0.0812 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - 2s/epoch - 85ms/step
# Epoch 17/200
# 26/26 - 1s - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - 1s/epoch - 46ms/step
# Epoch 18/200
# 26/26 - 1s - loss: 0.0622 - mean_squared_error: 0.0622 - val_loss: 0.0558 - val_mean_squared_error: 0.0558 - 1s/epoch - 47ms/step
# Epoch 19/200
# 26/26 - 1s - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.0481 - val_mean_squared_error: 0.0481 - 1s/epoch - 46ms/step
# Epoch 20/200
# 26/26 - 1s - loss: 0.0463 - mean_squared_error: 0.0463 - val_loss: 0.0409 - val_mean_squared_error: 0.0409 - 1s/epoch - 48ms/step
# Epoch 21/200
# 26/26 - 1s - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - 1s/epoch - 47ms/step
# Epoch 22/200
# 26/26 - 1s - loss: 0.0325 - mean_squared_error: 0.0325 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 - 1s/epoch - 46ms/step
# Epoch 23/200
# 26/26 - 1s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0256 - val_mean_squared_error: 0.0256 - 1s/epoch - 47ms/step
# Epoch 24/200
# 26/26 - 1s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - 1s/epoch - 47ms/step
# Epoch 25/200
# 26/26 - 2s - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - 2s/epoch - 76ms/step
# Epoch 26/200
# 26/26 - 2s - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - 2s/epoch - 85ms/step
# Epoch 27/200
# 26/26 - 1s - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0169 - val_mean_squared_error: 0.0169 - 1s/epoch - 47ms/step
# Epoch 28/200
# 26/26 - 1s - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 1s/epoch - 46ms/step
# Epoch 29/200
# 26/26 - 1s - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 1s/epoch - 46ms/step
# Epoch 30/200
# 26/26 - 1s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 1s/epoch - 45ms/step
# Epoch 31/200
# 26/26 - 1s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 1s/epoch - 45ms/step
# Epoch 32/200
# 26/26 - 1s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 1s/epoch - 47ms/step
# Epoch 33/200
# 26/26 - 1s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 1s/epoch - 47ms/step
# Epoch 34/200
# 26/26 - 1s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 1s/epoch - 45ms/step
# Epoch 35/200
# 26/26 - 2s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 2s/epoch - 77ms/step
# Epoch 36/200
# 26/26 - 2s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 2s/epoch - 87ms/step
# Epoch 37/200
# 26/26 - 1s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 1s/epoch - 46ms/step
# Epoch 38/200
# 26/26 - 1s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 1s/epoch - 46ms/step
# Epoch 39/200
# 26/26 - 1s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 1s/epoch - 49ms/step
# Epoch 40/200
# 26/26 - 1s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 1s/epoch - 46ms/step
# Epoch 41/200
# 26/26 - 1s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - 1s/epoch - 45ms/step
# Epoch 42/200
# 26/26 - 1s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - 1s/epoch - 46ms/step
# Epoch 43/200
# 26/26 - 1s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - 1s/epoch - 45ms/step
# Epoch 44/200
# 26/26 - 1s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - 1s/epoch - 45ms/step
# Epoch 45/200
# 26/26 - 2s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - 2s/epoch - 74ms/step
# Epoch 46/200
# 26/26 - 2s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - 2s/epoch - 85ms/step
# Epoch 47/200
# 26/26 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - 1s/epoch - 45ms/step
# Epoch 48/200
# 26/26 - 1s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - 1s/epoch - 46ms/step
# Epoch 49/200
# 26/26 - 2s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - 2s/epoch - 68ms/step
# Epoch 50/200
# 26/26 - 3s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - 3s/epoch - 131ms/step
# Epoch 51/200
# 26/26 - 2s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - 2s/epoch - 90ms/step
# Epoch 52/200
# 26/26 - 4s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - 4s/epoch - 135ms/step
# Epoch 53/200
# 26/26 - 3s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - 3s/epoch - 103ms/step
# Epoch 54/200
# 26/26 - 2s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - 2s/epoch - 85ms/step
# Epoch 55/200
# 26/26 - 2s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - 2s/epoch - 58ms/step
# Epoch 56/200
# 26/26 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - 1s/epoch - 52ms/step
# Epoch 57/200
# 26/26 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - 1s/epoch - 48ms/step
# Epoch 58/200
# 26/26 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - 1s/epoch - 47ms/step
# Epoch 59/200
# 26/26 - 2s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 2s/epoch - 69ms/step
# Epoch 60/200
# 26/26 - 2s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 2s/epoch - 85ms/step
# Epoch 61/200
# 26/26 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 1s/epoch - 50ms/step
# Epoch 62/200
# 26/26 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 1s/epoch - 46ms/step
# Epoch 63/200
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 1s/epoch - 45ms/step
# Epoch 64/200
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 1s/epoch - 47ms/step
# Epoch 65/200
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 1s/epoch - 45ms/step
# Epoch 66/200
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 1s/epoch - 47ms/step
# Epoch 67/200
# 26/26 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 1s/epoch - 45ms/step
# Epoch 68/200
# 26/26 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 1s/epoch - 45ms/step
# Epoch 69/200
# 26/26 - 2s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 2s/epoch - 61ms/step
# Epoch 70/200
# 26/26 - 2s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 2s/epoch - 84ms/step
# Epoch 71/200
# 26/26 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 1s/epoch - 52ms/step
# Epoch 72/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 47ms/step
# Epoch 73/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 46ms/step
# Epoch 74/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 48ms/step
# Epoch 75/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 47ms/step
# Epoch 76/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 47ms/step
# Epoch 77/200
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 1s/epoch - 47ms/step
# Epoch 78/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 46ms/step
# Epoch 79/200
# 26/26 - 2s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 2s/epoch - 65ms/step
# Epoch 80/200
# 26/26 - 2s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 2s/epoch - 80ms/step
# Epoch 81/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 54ms/step
# Epoch 82/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 48ms/step
# Epoch 83/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 45ms/step
# Epoch 84/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 47ms/step
# Epoch 85/200
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 1s/epoch - 46ms/step
# Epoch 86/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 44ms/step
# Epoch 87/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 45ms/step
# Epoch 88/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 47ms/step
# Epoch 89/200
# 26/26 - 2s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 2s/epoch - 64ms/step
# Epoch 90/200
# 26/26 - 2s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 2s/epoch - 82ms/step
# Epoch 91/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 52ms/step
# Epoch 92/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 44ms/step
# Epoch 93/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 46ms/step
# Epoch 94/200
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 44ms/step
# Epoch 95/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 46ms/step
# Epoch 96/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 1s/epoch - 45ms/step
# Epoch 97/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 45ms/step
# Epoch 98/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 46ms/step
# Epoch 99/200
# 26/26 - 2s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 2s/epoch - 61ms/step
# Epoch 100/200
# 26/26 - 2s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 2s/epoch - 84ms/step
# Epoch 101/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 54ms/step
# Epoch 102/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 45ms/step
# Epoch 103/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 45ms/step
# Epoch 104/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 47ms/step
# Epoch 105/200
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 47ms/step
# Epoch 106/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 1s/epoch - 47ms/step
# Epoch 107/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 46ms/step
# Epoch 108/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 45ms/step
# Epoch 109/200
# 26/26 - 2s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 2s/epoch - 66ms/step
# Epoch 110/200
# 26/26 - 2s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 2s/epoch - 85ms/step
# Epoch 111/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 51ms/step
# Epoch 112/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 45ms/step
# Epoch 113/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 46ms/step
# Epoch 114/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 47ms/step
# Epoch 115/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 45ms/step
# Epoch 116/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 46ms/step
# Epoch 117/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 48ms/step
# Epoch 118/200
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 1s/epoch - 48ms/step
# Epoch 119/200
# 26/26 - 2s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 2s/epoch - 69ms/step
# Epoch 120/200
# 26/26 - 2s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 2s/epoch - 84ms/step
# Epoch 121/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 48ms/step
# Epoch 122/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 46ms/step
# Epoch 123/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 45ms/step
# Epoch 124/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 46ms/step
# Epoch 125/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 45ms/step
# Epoch 126/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 47ms/step
# Epoch 127/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 47ms/step
# Epoch 128/200
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 47ms/step
# Epoch 129/200
# 26/26 - 2s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 2s/epoch - 69ms/step
# Epoch 130/200
# 26/26 - 2s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 2s/epoch - 83ms/step
# Epoch 131/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 1s/epoch - 49ms/step
# Epoch 132/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 133/200
# 26/26 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 2s/epoch - 62ms/step
# Epoch 134/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 135/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 136/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 46ms/step
# Epoch 137/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 138/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 46ms/step
# Epoch 139/200
# 26/26 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 2s/epoch - 74ms/step
# Epoch 140/200
# 26/26 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 2s/epoch - 84ms/step
# Epoch 141/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 142/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 46ms/step
# Epoch 143/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 46ms/step
# Epoch 144/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 48ms/step
# Epoch 145/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 146/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 147/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 148/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 149/200
# 26/26 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 2s/epoch - 77ms/step
# Epoch 150/200
# 26/26 - 2s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 2s/epoch - 81ms/step
# Epoch 151/200
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 152/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 153/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 154/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 45ms/step
# Epoch 155/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 156/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 1s/epoch - 47ms/step
# Epoch 157/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 158/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 159/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 66ms/step
# Epoch 160/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 85ms/step
# Epoch 161/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 50ms/step
# Epoch 162/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 163/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 164/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 165/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 166/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 167/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 168/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 44ms/step
# Epoch 169/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 64ms/step
# Epoch 170/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 80ms/step
# Epoch 171/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 54ms/step
# Epoch 172/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 173/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 174/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 175/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 176/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 177/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 178/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 179/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 61ms/step
# Epoch 180/200
# 26/26 - 2s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 84ms/step
# Epoch 181/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 54ms/step
# Epoch 182/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 183/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 184/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 185/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 186/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 187/200
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 188/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 48ms/step
# Epoch 189/200
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 64ms/step
# Epoch 190/200
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 80ms/step
# Epoch 191/200
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 2s/epoch - 62ms/step
# Epoch 192/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 193/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 194/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 45ms/step
# Epoch 195/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 48ms/step
# Epoch 196/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 47ms/step
# Epoch 197/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 198/200
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 1s/epoch - 46ms/step
# Epoch 199/200
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 2s/epoch - 58ms/step
# Epoch 200/200
# 26/26 - 2s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 2s/epoch - 83ms/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 10, 8)]              0         []
#
#  rnn_4 (RNN)                 (None, 10, 64)               5376      ['input_3[0][0]']
#
#  dense_6 (Dense)             (None, 10, 8)                520       ['rnn_4[0][0]']
#
#  add_4 (Add)                 (None, 10, 8)                0         ['dense_6[0][0]',
#                                                                      'input_3[0][0]']
#
#  rnn_5 (RNN)                 (None, 10, 64)               5376      ['add_4[0][0]']
#
#  dense_7 (Dense)             (None, 10, 8)                520       ['rnn_5[0][0]']
#
#  add_5 (Add)                 (None, 10, 8)                0         ['dense_7[0][0]',
#                                                                      'input_3[0][0]']
#
#  dense_8 (Dense)             (None, 10, 2)                18        ['add_5[0][0]']
#
# ==================================================================================================
# Total params: 11810 (46.13 KB)
# Trainable params: 11810 (46.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=False, show_layer_activations=True)

# %%
model.save('iclstm_scaled.h5')
# model = tf.keras.models.load_model('iclstm.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# The FLOPs is:97428

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('ICLSTM Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
"""
    equation for the stability ellipse is 1060x^2 + 44xy + 0.52y^2 - 372 = 0
"""
# prepare x and y coordinates for plotting the stability region
y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass


plt.figure(figsize=(10,10))

# # plot the first 10 samples and their trajectories
y_predict = model.predict(X_test)
print(y_predict.shape)

y_predict = y_predict.reshape(-1,2)
y_predict = scaler_y.inverse_transform(y_predict)
y_predict = y_predict.reshape(-1,num_step,2)

X_plot = X_test.reshape(-1,num_dims)
X_plot = scaler_X.inverse_transform(X_plot)
X_plot = X_plot.reshape(-1,num_step,num_dims)

for i in range(50):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls='-', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls='-')

# plot stability region
plt.plot(x_lower, y_plot, color='steelblue', label='stability region')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
plt.show()
# Out:
# <ipython-input-32-e5d2588824eb>:12: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
# 116/116 [==============================] - 1s 6ms/step
# (3706, 10, 2)

# %%
print(y_predict[85, :, 0])
print(y_test[85, :, 0])
# Out:
# [45.189278 46.430893 47.179363 47.800816 48.374638 48.97375  49.628532
#  50.40076  51.36434  52.67188 ]
# [43.76710785 44.69929931 45.64164627 46.59464478 47.55880348 48.53464356
#  49.52269879 50.5235154  51.53765195 52.56567921]

# %%
print(y_predict[15, :, 0])
print(y_test[15, :, 0])
# Out:
# [-42.169407 -41.522182 -40.411083 -39.759087 -38.936737 -38.237816
#  -37.38472  -36.482437 -35.312397 -33.824673]
# [-44.08771357 -43.03954631 -41.98778864 -40.93213046 -39.87224622
#  -38.807794   -37.73841457 -36.66373034 -35.5833442  -34.49683835]
